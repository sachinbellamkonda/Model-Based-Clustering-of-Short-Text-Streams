# %%
import json
import random
import os
import re
import time
import copy
import statistics
import collections
import math
import glob
import numpy as np
from sklearn import metrics

# %%
dataDir=r"C:\Users\sachin\Desktop\mtp\sachin\data"

# %%
dataset="News"

# %%
wordToIdMap={}
wordList=[]

# %%
class Document:

    def __init__(self, text, wordToIdMap, wordList, documentID):
        self.documentID  = documentID
        self.wordIdArray = []
        self.wordFreArray = []
        V = len(wordToIdMap)
        wordFreMap = {}
        ws = text.strip().split(' ')
        for w in ws:
            if w not in wordToIdMap:
                V += 1
                wId = V
                wordToIdMap[w] = V
                wordList.append(w)
            else:
                wId = wordToIdMap[w]

            if wId not in wordFreMap:
                wordFreMap[wId] = 1
            else:
                # wordFreMap[wId] = wordFreMap[wId] + 1
                wordFreMap[wId] = 1
        self.wordNum = wordFreMap.__len__()
        w = 0
        for wfm in wordFreMap:
            self.wordIdArray.append(wfm)
            self.wordFreArray.append(wordFreMap[wfm])
            w += 1

# %%
class DocumentSet:

    def __init__(self, dataDir, wordToIdMap, wordList):
        self.D = 0  # The number of documents
        # self.clusterNoArray = []
        self.documents = []
        with open(dataDir) as input:
            line = input.readline()
            while line:
                self.D += 1
                obj = json.loads(line)
                text = obj['textCleaned']
                document = Document(text, wordToIdMap, wordList, int(obj['Id']))
                self.documents.append(document)
                line = input.readline()
        print("number of documents is ", self.D)

# %%
documentSet = DocumentSet(os.path.join(dataDir,dataset), wordToIdMap, wordList)
documentSet
# Out:
# number of documents is  30322

# %%
words_csv={}
true_c={}

# %%
with open(os.path.join(dataDir,dataset)) as input:
        line = input.readline()
        k=0
        while line:
            k=k+1
            obj = json.loads(line)
            text = obj['textCleaned']
            true_c[obj['Id']]=obj['clusterNo']
            
            #print( obj['Id']+ "   " +text)
            #words_csv[k]=text
            line = input.readline()
            if ("" == line):break;

# %%
true_c
# Out:
# {'000001': 9,
#  '000002': 23,
#  '000003': 27,
#  '000004': 9,
#  '000005': 3,
#  '000006': 10,
#  '000007': 9,
#  '000008': 1,
#  '000009': 23,
#  '000010': 20,
#  '000011': 24,
#  '000012': 30,
#  '000013': 4,
#  '000014': 24,
#  '000015': 10,
#  '000016': 26,
#  '000017': 12,
#  '000018': 23,
#  '000019': 7,
#  '000020': 4,
#  '000021': 22,
#  '000022': 21,
#  '000023': 29,
#  '000024': 31,
#  '000025': 7,
#  '000026': 9,
#  '000027': 20,
#  '000028': 8,
#  '000029': 21,
#  '000030': 7,
#  '000031': 9,
#  '000032': 22,
#  '000033': 19,
#  '000034': 26,
#  '000035': 25,
#  '000036': 29,
#  '000037': 27,
#  '000038': 9,
#  '000039': 29,
#  '000040': 14,
#  '000041': 10,
#  '000042': 7,
#  '000043': 29,
#  '000044': 7,
#  '000045': 30,
#  '000046': 7,
#  '000047': 4,
#  '000048': 14,
#  '000049': 4,
#  '000050': 23,
#  '000051': 1,
#  '000052': 13,
#  '000053': 8,
#  '000054': 14,
#  '000055': 4,
#  '000056': 4,
#  '000057': 26,
#  '000058': 32,
#  '000059': 14,
#  '000060': 9,
#  '000980': 30,
#  '000981': 7,
#  '000982': 21,
#  '000983': 14,
#  '000984': 20,
#  '000985': 19,
#  '000986': 29,
#  '000987': 27,
#  '000988': 26,
#  '000989': 7,
#  '000990': 21,
#  '000991': 23,
#  '000992': 9,
#  '000993': 3,
#  '000994': 9,
#  '000995': 27,
#  '000996': 27,
#  '000997': 5,
#  '000998': 23,
#  '000999': 21,
#  '001000': 22,
#  ...}

# %%
with open(os.path.join(dataDir,dataset)) as input:
        line = input.readline()
        k=0
        while line:
            k=k+1
            obj = json.loads(line)
            text = obj['textCleaned']
            
            print( obj['Id']+ "   " +text)
            words_csv[k]=text
            line = input.readline()
            if ("" == line):break;
# Out:
# 000001   toyota recall vehicle quality woe mount reuters
# 000002   faster flying pat amtrak slogan
# 000003   saving house heating cooling
# 000004   google alert luxury car news result luxury car toyota recall vehicle
# 000005   haitian politics duvalier haiti map mand yo ac
# 000006   hope museum egyptian antiquity will real shame jan
# 000007   nhtsa investigation electronic flaws toyotas suddenly accelerated submitted
# 000008   bbc exodus huge bill moving staff uk pic
# 000009   power problem amtrak northeast
# 000010   taco bell defends mixture seasoned meat ap ap taco bell official tuesday rejected claim
# 000011   super bowl xlv fan boot super bowl
# 000012   news olbermann join al gore current tv ny times reports tv star keith olbermann will join current medium
# 000013   mexican soldier seized giant catapult believed fling drug mexico border
# 000014   league blame super seat fiasco ap
# 000015   looters smashed egypt national museum damaged priceless artifact picture
# 000016   ohio unemployment families suffering ak steel pulling plant area
# 000017   wikileaks nobel peace prize profit motive
# 000018   service today pm service
# 000019   pakistani court block release man embassy official diplomatic immunity acted
# 000020   caller reports morning indicate border resident mexico confirming middle eastern men involved border violence
# 000021   federal judge key health care reform cnn blogs
# 000022   dtn usa ill high court mull emanuel mayoral chicago election official printing mayoral
# 000023   fox news gene fishes sources debate al gore global warming argument
# 000024   special olympics provide needed boost olympics
# 000025   negotiations continue pakistan detained diplomat voice america
# 000026   clear toyota electronic throttle reuters
# 000027   taco bell slammed beef label chipotle top food win
# 000028   uk news phone hacking row pm called police
# 000029   breaking news rahm emanuel officially mayoral ballot lt lt failed
# 000030   pakistan news armed diplomat kill pakistan consulate employee shot killed people
# 000031   clear toyota electronic throttle washington reuters government investigation link
# 000032   reason federal judge individual mandate health care overhaul declared void obamacare
# 000033   politics governor cuomo budget seek sham york reuters york governor
# 000034   weather unemployment figure washington number people applying unemployment benefit rose sh
# 000035   police state tsa dictator friend mubarak jan wikileaks
# 000036   state gr mayor talks technology budget cuts global warming
# 000037   day add insulation blanket improve water heater efficiency reducing heat loss
# 000038   government find evidence electronic caused sudden acceleration incident toyota vehicle
# 000039   news neighbor east global warming harrison schmitt
# 000040   therite speaking language individual learned heard
# 000041   national museum protester formed human shield museum defend looting
# 000042   diplomatic immunity raymond davis case teeth
# 000043   satellite climate model evidence substantial manmade climate change climatechange climaterealism
# 000044   diplomat killed defense washington post
# 000045   msnbc host keith olbermann head current tv ap ap keith olbermann month abruptly left
# 000046   lahore court order staffer hindu ctv lahore court order lahore high
# 000047   mexican police arrest acapulco including man linked people reuters
# 000048   hopkins rite top box office
# 000049   congress gun lobby loophole increasingly heart mexican drug war
# 000050   cutting rail funding hurt america transportation future
# 000051   bbc strictly wardrobe wedding dressmaker save service
# 000052   today video buzz grows ahead oprah personal announcement
# 000053   press mount investigate police handling phone hacking claim independent
# 000054   rite leads slow box office weekend exorcism thriller rite topped slow weekend movie box
# 000055   gun fueling violence associated mexican drug cartel
# 000056   drug catapult mexico border
# 000057   thoughts changed hasn forward adult room
# 000058   social web state union stats provided twitter facebook
# 000059   sir anthony hopkins tops box office rite slow weekend box office
# 000060   citing fuel system problem toyota expands recall lexus sedans
# 000061   fla judge strike health overhaul pensacola fla ap federal judge florida obama
# 000062   demand release diplomat killed united states demanded release amer
# 000063   mexico suspected trafficker slain shootout mexican authority suspected drug gang gunman
# 000064   clegg denies coulson exit damage nick clegg denies government damaged impending departure
# 000065   reading keith olbermann move tv
# 000066   obama push unemployment benefits condition extending tax rates creating job unemployment
# 000067   energy efficient energy efficient solar pool covers
# 000068   watching rite tony scary movie ll sir anthony hopkins
# 000069   nist guidance tackles public cloud security
# 000070   fed judge strikes entire healthcare law obamacare healthcare
# 000071   london hostage death threat gt raymond davis australian pakistan embassy issued official diplomatic
# 000072   fans denied access seat superbowl
# 000073   diplomat ordered held pakistan cnn
# 000074   bloody hell leslie ash lee suing phone hacking hacked bottom food chain
# 000075   oprah half sister
# 000076   comeback plea thorpe
# 000077   nist report aim help agency deploy cloud apps computerworld
# 000078   review rite fstr film reminds exorci
# 000079   business treated customer nfl treat fan wouldn exist
# 000080   emanuel candidacy doubt ill court ruling national suddenly campaign replace
# 000081   tcot drug smugglers catapults hurl pot border
# 000082   omg love taco bell law firm sue taco bell claim beef label misleading
# 000083   lexus included latest toyota recall
# 000084   save bbc service drama inquiry announcement service will slash spending
# 000085   durbin chair hearing healthcare law hill tcot obamacare
# 000086   haitian government issued passport president jean bertrand aristide enabling
# 000087   bbc news update pakistan extends man custody pakistani court extends detention day
# 000088   hides taco bell beef
# 000089   taco bell releases statement class action lawsuit beef
# 000090   jobs obama focus job loss unemployment figure steady percent
# 000091   study links looming food supply catastrophe global warming
# 000092   watching white stripe
# 000093   birthday cards drug smugglers great hide london cnn drug smuggler eve
# 000094   gop leader mcconnell force senate vote healthcare repeal
# 000095   taco bell clarifies lawsuit bogus seasoned beef recipe beef food gizmodo
# 000096   prince william kate middleton wedding guest invited telegraph uk
# 000097   gov cuomo medicaid plan albany jacob gershman gov andrew cuomo effort strip lawmaker
# 000098   video drug smugglers medieval catapult launches pot border
# 000099   toyota recall car cnn
# 000100   national geographic agw propaganda arm global warming movement sadly
# 000101   health care litigation insurance mandate
# 000102   nist guidance tackles public cloud security
# 000103   hello lax tsa moment horrible super trip will week night
# 000104   sound politics global warming update global warming update record snowfall north america
# 000105   defending reputation learn
# 000106   drive flat screen tv efficiency
# 000107   illinois supreme court appellate court ruling rahm emanuel will ballot chicago mayor
# 000234   rite today stephen excellent movie
# 000235   destroy fire fighter van protester museum close ndp
# 000236   white stripes man fucking suck
# 000237   ill high court emanuel chicago mayor
# 000238   athletes prepare winter games winter games main special olympics competition event
# 000239   judge strike healthcare reform law conspiracy
# 000240   power problem suspend nj transit service northeast corridor north jersey coast jennifer brown
# 000241   hear interview matt baglio journalist author book rite lt plan movie
# 000242   amtrak nj senator propose hudson rail tunnel
# 000243   toyota recall involves lexus models
# 000244   police launch inquiry phone hacking reuters jan pm est mu
# 000245   oil sunday train going attack amtrak
# 000246   pot firing catapult arizona mexico border ap
# 000247   ohio unemployment families suffering
# 000248   surprised hear news phone hacking involves person
# 000249   winning future aka wtf unemployment january tcot
# 000250   nfl super bowl seat fiasco
# 000251   joe buck seat couldn super bowl
# 000252   monster storm brings climate blame
# 000253   seat ready super bowl fan cowboys stadium arlington texas nfl announced
# 000254   bachmann response state union cnn political ticker cnn blogs
# 000255   nazi germany increasingly internal passport satisfy
# 000256   record snowstorm global warming
# 000257   taco bell reveals secret beef recipe suing fox news latino
# 000258   rite safe horror film devil time plain dealer
# 000259   jobless claim pushed higher wintry weather number people applying unemployment benefit rose sharpl
# 000260   bag hot algore global warming wet dream match hell tcot
# 000261   toyota recalls vehicles quality issues
# 000262   mexico hit man linked acapulco death caught ap ap mexican official nabbed alleged
# 000263   nobel peace prize wikileaks
# 000264   guess cycle global warming started earlier scientist thought
# 000265   economy feel kid ny times article impact ohio family unemployment
# 000266   jobs wrong places memo president dear president state union add
# 000267   dtn hollywood rite win box office oscar film bump ap ap anthony hopkins horror film
# 000268   alabama law firm claim tacobell beef meet min govt label beef suit claim meat
# 000269   hillary clinton flagged judicial reform essential mexico drug war
# 000270   yr ago today headline panic toyota owner sticking throttle spark recall week
# 000271   official face murder rap pakistan fury grows
# 000272   murder accused diplomat spy report
# 000273   trial photo audio defense fund info video arrest
# 000274   news toyota recall auto quality woe mount tokyo reuters toyota motor corp wou
# 000275   toyota announces recall denver post tokyo toyota recalling vehicle worldwide
# 000276   embassy staffer charged pakistan
# 000277   don ve train crawley time
# 000278   taco bell beef lawsuit public ap ap taco bell legal beef meat
# 000279   coming airport modesty change
# 000280   pelosi unemployment percent prevented depression
# 000281   pakistani shooting case tied isi
# 000282   opinion taco bell suit exposes ignorance meat shortly news taco bell lawsuit ou
# 000283   reuters nfl invite seat fan super bowl sb
# 000284   overload news pakistan court extends detention diplomat reuters dawn court extends
# 000285   rite strings attached top honor weekend box office
# 000286   installing photovoltaic
# 000287   blog dhs tsa increase security risk
# 000288   anthony hopkins takes rite top box office
# 000289   white house pursue health care appeal judge rejects entire law yahoo finance
# 000290   watched therite sister pretty crazy movie
# 000291   forward tsa screening haven laid couple week
# 000292   taco bell humor social media dig beef scandal
# 000293   spy politicians british aide prime minister resigns
# 000294   updated ten myths efficient light guy
# 000295   kickoff loom worker scurry finalize cowboys stadium three hour kickoff cowboys stadium
# 000296   installing solar photovoltaic system generate electricity free energy sun
# 000297   clear global warming lie convince actual case
# 000298   listening don white stripes
# 000359   rite hella spooky thumb
# 000360   white stripe break good
# 000361   extreme weather sign global warming gregory connecticut average temperature
# 000362   gt gt toyota recall news lt lt
# 000363   tsa testing modest full body scanner msnbc
# 000364   people denied seat superbowl expected refunded time amount
# 000365   taco bell fight beef lawsuit ad push taco bell launching advertising campaign friday fig
# 000366   terrorism watch police pledge robust probe phone hacking police will leave stone terrorismwatch org
# 000367   egypt army secures museum pharaonic treasure report cairo reuters army unit secured egyptian mu
# 000368   judge rule healthcare law federal judge florida struck president barack obama
# 000369   climatechange high food price contributing mideast unrest climate progress
# 000370   trial photo audio defense fund info video arrest
# 000371   ft editor press risk political retribution phone hacking scandal
# 000372   white stripes breaking
# 000373   midnight showing night anthony hopkins movie rite awesome super
# 000374   olbermann confirms current tv job twitter lost remote olbermann confirms current tv job twitter
# 000375   ap illinois supreme court rahm emanuel ballot chicago mayor
# 000376   illinois supreme court rahm emanuel ballot
# 000377   obama state union speech full text prior president barack obama state union speech
# 000378   rite good anthony hopkins pull creepy well refer father
# 000379   shouldn bbc parts service
# 000380   latin america news mexican trafficker catapult drug border afp afp mexican drug yahoo
# 000381   stadium finished fan left temporary seat cowboys stadium fin
# 000382   post sen mary mayor mitch reax state union mention gulf
# 000383   judge overturn obama health care law nbc
# 000384   ap toyota recall vehicle fuel leak
# 000385   taco bell responds meat lawsuit globe mail
# 000386   telling social web state union stats
# 000387   american diplomat charged double murder pakistan called drone
# 000388   haiti issues passport leader aristide port au prince haitian government commondreams org
# 000389   donald rumsfeld reflects writing memoir ap news
# 000390   village school officials tax cap budget cuts
# 000391   court rules rahm emanuel ineligible mayor chicago opponents white house
# 000392   taco bell fight beef lawsuit taco bell launching advertising campaign today fight
# 000393   rahm stay chi mayoral ballot dbl standard city residency rule public worker nytimes
# 000394   king speech expands theater film news rite mechanic box office entry des
# 000395   taco bell meat law firm claim lawsuit taco bell false advertising refers
# 000396   illinois court emanuel stay chicago ballot chicago reuters white house chief st news
# 000397   super bowl ticket holder seat cowboys stadium nfl
# 000398   toyota recall lexus gs vehicle detroit news
# 000399   jerry jones issue super bowl xlv statement
# 000400   npr news ill high court emanuel chicago mayor
# 000401   tsa starts testing scanners don naked body despite protest tsa ther
# 000402   qatar fifa cup stadiums
# 000403   rahm emanuel hit chicago roadblock
# 000404   fans denied access seat super bowl superbowl steelers cowboys suck
# 000405   green tips
# 000406   cold global warming big deal
# 000407   bbc news clegg denies coulson exit damage nick clegg denies government damaged impending
# 000408   federal judge fla rule health care plan live better
# 000409   california resident sue taco bell false advertising chris lawsuit filed federal court
# 000410   keith will ko current tv keith extremely role progressive ideal fok
# 000411   cnn jesse ventura slam tsa lawsuit count jesse ventura flier don junk touched
# 000412   latest news jesse ventura force tsa submission jennifer things pr guardian usa
# 000413   rite movie alright
# 000414   toyota recalls vehicles fuel
# 000415   judge rule obama health care law
# 000416   emanuel seeks ruling chicago race rahm emanuel president barack obama fb
# 000417   illinois high court review emanuel case illinois supreme court agreed review case challenging
# 000603   photo movie trailers rite trailer video hulu watch stream
# 000604   uk phone hacking probe spread acting head metropolitan police face question
# 000605   editorial high court protect voter press illinois supreme court ordered chicago
# 000606   fan air save heating cooling cost fan reduce summer air energy cost
# 000607   tsa testing body scanning system traveler pass scanner computer
# 000608   movie news channel box office anthony hopkins rite stuff friday movies
# 000609   post nfl knew week seat problem ap
# 000610   official pakistan face murder charge pakistan will pursue murder charge consular emplo
# 000611   republicans propose deep cut funding wide range target pbs amtrak
# 000612   governor budget idea democrats republicans budget includes idea
# 000613   court kick rahm emanuel chicago mayoral ballot guess leaving white house wasn good idea
# 000614   making energy efficient winter months
# 000615   diplomatic worker face murder charge pakistan shooting los angeles times
# 000616   fox global warming fails miserably care news network
# 000617   anthony hopkins rite knock strings attached cinema movie trailer ri
# 000618   falling work force jobless dip
# 000619   great idea hack nfl hopes replace ipads
# 000620   cuomo cuts spending budget plan
# 000621   mutilated bodies discovered mexico
# 000622   statement bbc service ahead staff briefing detail bbcworldservice
# 000623   illinois supreme court halt printing ballot rahm emanuel illinois supreme court chicago
# 000624   yesssss breaking il supreme court rule rahm emanuel will ballot
# 000625   unemployment rates state glance ap ap unemployment rate rose state month fresh
# 000626   jobless claim tumble week washington reuters claim unemployment benefit dropped expected
# 000627   unemployment claim drop
# 000628   david cameron fears phone hacked hmmmm funny wonder
# 000629   initial probe report davis case presented court sunny
# 000630   keith olbermann current tv nyt news keith newest keith olbermann
# 000631   extreme weather create global food crisis joseph romm
# 000632   anthony hopkins takes rite top box office
# 000633   obama face sputnik moment declaring nation face big decision confronted
# 000634   comment emanuel ballot access rahm emanuel stay ballot illinois supreme cou
# 000635   sports digest fifa discus moving cup qatar summer winter san jose fifa
# 000636   taco bell answer lawsuit beef
# 000637   security built tsa touch junk will bust left side face tcot
# 000638   ill high court emanuel chicago mayor ap
# 000639   ll white stripes
# 000640   find defect toyota electronic throttle
# 000641   obama nation google facebook american innovation state union
# 000642   al gore explains global warming matt global warming guru vice
# 000643   msnbc host keith olbermann head current tv congrats current
# 000644   nfl fan ticket seat scofflaw weren seat tickets superbowl
# 000645   met police reopen investigation phone hacking news ian sacked
# 000646   wisconsin performed pretty well recession true unemployment avg
# 000647   oprah family secret news views news literally shook heart time
# 000648   source uk leader feared hacked
# 000649   gun raid cartel work arizona
# 000650   ill court throw emanuel chicago ballot ap ap day ago rahm emanuel
# 000651   judge strike obama healthcare law reuters
# 000652   update lt gov seek support cuomo budget
# 000653   keith olbermann headed current tv report msnbc top msnbc headline msnbc anchor keith
# 000654   haiti allows president aristide return haitian politics interesting
# 000655   bbc service ax language service
# 000656   billion plan bring high speed rail
# 000657   oprah blockbuster announcement monday
# 000658   toyota recall cars worldwide fuel issues abc news
# 000659   well surprise good thing healthcare law declared
# 000660   judge strike healthcare reform law law men
# 000661   vinson rule entire hcr law lack clause entire text
# 000662   player report nfl invite fan lost seat super bowl washington post
# 000663   cuomo proposes deep cut suny cuny shameful
# 000664   emanuel ruling ll prevail roberto joined dozen supporter rally
# 000665   travel historic blizzard devastating air land travel
# 000666   blatter expects stay summer updates fifa president sepp blatter changed monday
# 000667   dead fish plan appeal court ruling removed chitown mayoral ballot fb
# 000668   drug smuggler second pot catapult
# 000669   heritage morning bell victory road repeal teaparty hcr
# 000670   taco bell percent real beef lawsuit claim
# 000671   obama health care overhaul ruled
# 000672   poll find oppose airport security measure money company los angeles times
# 000673   unemployment hits harder youth united states
# 000674   recalling toyota
# 000675   watchdog group question google relationship nsa community
# 000676   government electronic flaw toyotas ap
# 000677   rahm emanuel stays ballot chicago mayoral election filed news politics president obama ra
# 000678   extreme weather create global food crisis joseph romm
# 000679   global drama coming month drug ir major haiti aristide passport
# 000680   riding amtrak auto train tweet bad faster comfortable good food
# 000681   national guard finds pot firing catapult
# 000682   truth stand pakistanis killed diplomat david gt pl read comment
# 000683   toyota recall car cnn
# 000684   taco bell beef isn meat horror
# 000685   final numbers detroit auto bigger
# 000686   rahm emanuel chicago ballot news
# 000687   met fresh phone hacking probe police launch fresh investigation phone hacking receiving
# 000688   teams splash special olympics special olympics louisiana
# 000689   governor cuomo brought detail proposed budget today will painful
# 000690   rite amazing happy month love lt
# 000691   rite great great cast story
# 000692   amtrak gt sea min late europe china kick ass
# 000693   ut knoxville chancellor jimmy cheek issue ambitious goal reduce campus energy
# 000694   unemployment record american consumer news
# 000695   usa catapult drug drug smuggler marijuana arizona mexico
# 000696   supreme court agrees hear appeal decision knock rahm ballot chicago sun times
# 000697   asks pakistan release diplomat india news
# 000698   ten york city hospitals close governor cuomo proposed medicaid cuts
# 000699   will severe amazon drought affect rate global climate change
# 000700   lawsuit claim taco bell meat mixture percent beef change opinion food
# 000701   reward long service staff times
# 000702   taco bell law firm suing
# 000703   jobless claim tumble week washington reuters claim unemployment benefit dropped
# 000704   rite tops box office mechanic takes third jared
# 000705   court emanuel eligible chicago mayor
# 000706   taco bell fights ad campaign
# 000707   parent kid hospitals school arm cuomo budget union decry layoff warning
# 000708   hmm cnn reported economy gained job jan ppl street suez egypt figure outsource
# 000709   court halts chicago emanuel
# 000710   dtn news raymond davis released raymond davis american national killed
# 000711   ready call action call invest future create job country sotu
# 000712   ill court throw emanuel chicago ballot
# 000713   clear toyota electronics investigation toyota safety problem find electronic flaw
# 000714   sad white stripes split steam side project best moment
# 000715   health care law deemed illegal news press health care law deemed illegal news
# 000716   pot firing catapult arizona mexico border
# 000717   awesome business article global warming crazy stuff tree
# 000718   unreal sad story fan ticket super bowl seat
# 000719   reports italian polish medium claim robert kubica injured rally accident italy
# 000720   increase oil prices beneficial solar power solar energy focus point european union
# 000721   jobless claim tumble week washington reuters claim unemployment benefit dropped
# 000722   will missionary recognize haiti haitians aristide return helpless
# 000723   court emanuel eligible chicago mayor ny times pa habit place
# 000724   report private sector job january york private employer created net
# 000725   major cut bbc service bbc share friends top news entertainment ne
# 000726   business leader governor cuomo budget
# 000727   power problem delay light rail train service denver power problem train storage yard
# ...
# 030042   july justin knock knock live justin en knock knock live mtvhottest justin bieber
# 030043   special happened knockknocklive tuesday
# 030044   calling beliebers knocking lucky fan door tomorrow knockknocklive
# 
#wordToIdMap
#wordList
# Out:
# {1: 'toyota recall vehicle quality woe mount reuters',
#  2: 'faster flying pat amtrak slogan',
#  3: 'saving house heating cooling',
#  4: 'google alert luxury car news result luxury car toyota recall vehicle',
#  5: 'haitian politics duvalier haiti map mand yo ac',
#  6: 'hope museum egyptian antiquity will real shame jan',
#  7: 'nhtsa investigation electronic flaws toyotas suddenly accelerated submitted',
#  8: 'bbc exodus huge bill moving staff uk pic',
#  9: 'power problem amtrak northeast',
#  10: 'taco bell defends mixture seasoned meat ap ap taco bell official tuesday rejected claim',
#  11: 'super bowl xlv fan boot super bowl',
#  12: 'news olbermann join al gore current tv ny times reports tv star keith olbermann will join current medium',
#  13: 'mexican soldier seized giant catapult believed fling drug mexico border',
#  14: 'league blame super seat fiasco ap',
#  15: 'looters smashed egypt national museum damaged priceless artifact picture',
#  16: 'ohio unemployment families suffering ak steel pulling plant area',
#  17: 'wikileaks nobel peace prize profit motive',
#  18: 'service today pm service',
#  19: 'pakistani court block release man embassy official diplomatic immunity acted',
#  20: 'caller reports morning indicate border resident mexico confirming middle eastern men involved border violence',
#  21: 'federal judge key health care reform cnn blogs',
#  22: 'dtn usa ill high court mull emanuel mayoral chicago election official printing mayoral',
#  23: 'fox news gene fishes sources debate al gore global warming argument',
#  24: 'special olympics provide needed boost olympics',
#  25: 'negotiations continue pakistan detained diplomat voice america',
#  26: 'clear toyota electronic throttle reuters',
#  27: 'taco bell slammed beef label chipotle top food win',
#  28: 'uk news phone hacking row pm called police',
#  29: 'breaking news rahm emanuel officially mayoral ballot lt lt failed',
#  30: 'pakistan news armed diplomat kill pakistan consulate employee shot killed people',
#  31: 'clear toyota electronic throttle washington reuters government investigation link',
#  32: 'reason federal judge individual mandate health care overhaul declared void obamacare',
#  33: 'politics governor cuomo budget seek sham york reuters york governor',
#  34: 'weather unemployment figure washington number people applying unemployment benefit rose sh',
#  35: 'police state tsa dictator friend mubarak jan wikileaks',
#  36: 'state gr mayor talks technology budget cuts global warming',
#  37: 'day add insulation blanket improve water heater efficiency reducing heat loss',
#  38: 'government find evidence electronic caused sudden acceleration incident toyota vehicle',
#  39: 'news neighbor east global warming harrison schmitt',
#  40: 'therite speaking language individual learned heard',
#  41: 'national museum protester formed human shield museum defend looting',
#  42: 'diplomatic immunity raymond davis case teeth',
#  43: 'satellite climate model evidence substantial manmade climate change climatechange climaterealism',
#  44: 'diplomat killed defense washington post',
#  45: 'msnbc host keith olbermann head current tv ap ap keith olbermann month abruptly left',
#  46: 'lahore court order staffer hindu ctv lahore court order lahore high',
#  47: 'mexican police arrest acapulco including man linked people reuters',
#  48: 'hopkins rite top box office',
#  49: 'congress gun lobby loophole increasingly heart mexican drug war',
#  50: 'cutting rail funding hurt america transportation future',
#  51: 'bbc strictly wardrobe wedding dressmaker save service',
#  52: 'today video buzz grows ahead oprah personal announcement',
#  53: 'press mount investigate police handling phone hacking claim independent',
#  54: 'rite leads slow box office weekend exorcism thriller rite topped slow weekend movie box',
#  55: 'gun fueling violence associated mexican drug cartel',
#  56: 'drug catapult mexico border',
#  57: 'thoughts changed hasn forward adult room',
#  58: 'social web state union stats provided twitter facebook',
#  59: 'sir anthony hopkins tops box office rite slow weekend box office',
#  60: 'citing fuel system problem toyota expands recall lexus sedans',
#  61: 'fla judge strike health overhaul pensacola fla ap federal judge florida obama',
#  62: 'demand release diplomat killed united states demanded release amer',
#  63: 'mexico suspected trafficker slain shootout mexican authority suspected drug gang gunman',
#  64: 'clegg denies coulson exit damage nick clegg denies government damaged impending departure',
#  65: 'reading keith olbermann move tv',
#  66: 'obama push unemployment benefits condition extending tax rates creating job unemployment',
#  67: 'energy efficient energy efficient solar pool covers',
#  68: 'watching rite tony scary movie ll sir anthony hopkins',
#  69: 'nist guidance tackles public cloud security',
#  70: 'fed judge strikes entire healthcare law obamacare healthcare',
#  71: 'london hostage death threat gt raymond davis australian pakistan embassy issued official diplomatic',
#  72: 'fans denied access seat superbowl',
#  73: 'diplomat ordered held pakistan cnn',
#  74: 'bloody hell leslie ash lee suing phone hacking hacked bottom food chain',
#  75: 'oprah half sister',
#  76: 'comeback plea thorpe',
#  77: 'nist report aim help agency deploy cloud apps computerworld',
#  78: 'review rite fstr film reminds exorci',
#  79: 'business treated customer nfl treat fan wouldn exist',
#  80: 'emanuel candidacy doubt ill court ruling national suddenly campaign replace',
#  81: 'tcot drug smugglers catapults hurl pot border',
#  82: 'omg love taco bell law firm sue taco bell claim beef label misleading',
#  83: 'lexus included latest toyota recall',
#  84: 'save bbc service drama inquiry announcement service will slash spending',
#  85: 'durbin chair hearing healthcare law hill tcot obamacare',
#  86: 'haitian government issued passport president jean bertrand aristide enabling',
#  87: 'bbc news update pakistan extends man custody pakistani court extends detention day',
#  88: 'hides taco bell beef',
#  89: 'taco bell releases statement class action lawsuit beef',
#  90: 'jobs obama focus job loss unemployment figure steady percent',
#  91: 'study links looming food supply catastrophe global warming',
#  92: 'watching white stripe',
#  93: 'birthday cards drug smugglers great hide london cnn drug smuggler eve',
#  94: 'gop leader mcconnell force senate vote healthcare repeal',
#  95: 'taco bell clarifies lawsuit bogus seasoned beef recipe beef food gizmodo',
#  96: 'prince william kate middleton wedding guest invited telegraph uk',
#  97: 'gov cuomo medicaid plan albany jacob gershman gov andrew cuomo effort strip lawmaker',
#  98: 'video drug smugglers medieval catapult launches pot border',
#  99: 'toyota recall car cnn',
#  100: 'national geographic agw propaganda arm global warming movement sadly',
#  101: 'health care litigation insurance mandate',
#  102: 'nist guidance tackles public cloud security',
#  103: 'hello lax tsa moment horrible super trip will week night',
#  104: 'sound politics global warming update global warming update record snowfall north america',
#  105: 'defending reputation learn',
#  106: 'drive flat screen tv efficiency',
#  107: 'illinois supreme court appellate court ruling rahm emanuel will ballot chicago mayor',
#  108: 'displaced super bowl fan received post game field pas food beverage super bowl ticket year trailer superbowl',
#  109: 'cuts bbc full force stadium',
#  110: 'rahm emanuel appeals court rahm emanuel shouldn ballot chicago',
#  111: 'guess jack finally realized better meg bummer rip white stripes',
#  112: 'phone hacking row pm called police gordon brown police feared target',
#  113: 'white stripes will white stripes officially broken',
#  114: 'arizona bust mexico gun runner',
#  115: 'tweet raymond davis released pakistan',
#  116: 'mark penn state union obama win future',
#  117: 'obamacare struck stage set showdown federal judge monday struck',
#  118: 'americans filed claim unemployment benefit week better news analyst expected',
#  119: 'pls read discover fact',
#  120: 'illinois court emanuel stay chicago ballot chicago reuters white house chief staff rahm emanuel news',
#  121: 'earlier incident train service resumed residual delay',
#  122: 'saving energy solar power solar powered',
#  123: 'energy conservation tips south hills electric heating cooling',
#  124: 'el paso ju citizens unite protest border violence',
#  125: 'news diplomat kill pakistanis american diplomat pakistani city lahore shot',
#  126: 'team stated confident formula',
#  127: 'labour chief whip phone hacking claim nick brown suspicious landline call',
#  128: 'option raymond davis case daily express',
#  129: 'lol pot firing catapult mexican border',
#  130: 'initial jobless claim fall expected forex pros number people filed unemployment',
#  131: 'judge rule health care law mark arsenault washington federal judge florida',
#  132: 'breaking federal judge rule obamacare san francisco examiner',
#  133: 'taco bell meat problem lt problem sauce meat type matter gt',
#  134: 'obamacare meets death panel redstate tcot hcr teaparty politics',
#  135: 'report keith olbermann going current tv',
#  136: 'krauthammer global warming religion brad johnson thinkprogress',
#  137: 'release final toyota investigation finding',
#  138: 'incredible footage ice falling super bowl stadium people injured super bowl si',
#  139: 'st louis unemployment percent',
#  140: 'day boehner job er depression unemployment hr fair tax promo',
#  141: 'bus route amtrak sidewalk trail house rs cut funding easy',
#  142: 'lahore shooting pakistan refuses release american killed',
#  143: 'tsa crime',
#  144: 'cup will hosted afc president mohamed bin',
#  145: 'pot firing catapult arizona mexico border clt',
#  146: 'judges ruled rahm tied backer opponent',
#  147: 'rite afternoon sir hopkins delivers creep year well',
#  148: 'uk police vow full inquiry phone hacking ap',
#  149: 'raymond davis linked terrorism pakistan',
#  150: 'queensland floods prove alarmist warmism making religion science climaterealism',
#  151: 'pakistani judge order american held day court thursday ordered detention american offic',
#  152: 'die hour juarez people killed hour ciudad juarez mexico including',
#  153: 'taco bell sued meat percent beef foxnews',
#  154: 'oprah winfrey big family secret',
#  155: 'die hour juarez people killed hour ciudad juarez mexico including',
#  156: 'employment gaining speed jobless rate washington reuters employment shifted higher',
#  157: 'illinois appellate court action rahm emanuel chicago ballot rahm idea tcot sgp',
#  158: 'written transcript tweet call nsa freedom office',
#  159: 'darling user gen set current tv score darling progressive left keith olbermann',
#  160: 'reuters tcot cuomo call york budget process sham',
#  161: 'governor cuomo budget proposal eliminates funding healthy families york',
#  162: 'rite captures friday box office',
#  163: 'split pea soup plenty cheese tale rite opening',
#  164: 'super bowl record shot unfinished seats',
#  165: 'anthony hopkins rite kn',
#  166: 'horrible rite win weak box office weekend optimistic outlook people',
#  167: 'movie therite crazy hell shook good movie',
#  168: 'current tv keith olbermann host msnbc countdown keith olbermann',
#  169: 'google blog auto industry fast start motor city',
#  170: 'fucking awesome jesse jesse ventura slam tsa lawsuit',
#  171: 'police promise robust phone hacking inquiry',
#  172: 'judge rule health law law mandatory insurance hcr aca',
#  173: 'queensland floods prove alarmist warmism making religion science climaterealism',
#  174: 'taco bell fight beef lawsuit ad push ap taco bell rising promotion info',
#  175: 'meat high quality mediapost beef taco bell buzz suffering mediapost',
#  176: 'going amazing constitutional showdown reach supreme court',
#  177: 'white house unveils year billion high speed rail plan',
#  178: 'taco bell social media emerge beef scandal lt',
#  179: 'toyota recall vehicle',
#  180: 'al jazeera protestors create human shield egyptian museum protect egypt egipto jan',
#  181: 'record rite long dry',
#  182: 'nsa cyber command space power leap castle trust carroll maryland trust national security case',
#  183: 'rule rahm emanuel isn chicago resident',
#  184: 'fan turned super bowl xlv seating football news nfl usatoday',
#  185: 'official doesn news easier av club white stripes break',
#  186: 'man hour judge vinson obamacare second ruling',
#  187: 'warns mexican drug cartel violence el paso texas united states ahn tcot tlot',
#  188: 'taco bell social media ward pr crisis',
#  189: 'wash times misrepresents glacier study attack global warming science medi',
#  190: 'emanuel face election setback rahm emanuel white house chief staff waging desperate bid',
#  191: 'jobless claim tumble week washington reuters claim unemployment benefit dropped',
#  192: 'current tv keith olbermann host msnbc countdown keith olbermann',
#  193: 'super bowl fan denied seat cowboys stadium ready super bowl game ab',
#  194: 'keith olbermann headed current tv report ny times announcement planned tomorrow',
#  195: 'long term unemployed face stigma job search',
#  196: 'nevada gop healthcare reform decision governor senator',
#  197: 'train service resumed residual delay',
#  198: 'department agriculture beef flesh cattle tacobell class action law suit',
#  199: 'truth ain beef alabama law firm claim lawsuit taco bell false adv',
#  200: 'bbc service plan job cut ap ap bbc wednesday plan cut job tha',
#  201: 'news white stripes broke today',
#  202: 'pakistan court block handing diplomat reuters',
#  203: 'looters broke museum destroyed pharaonic mummy late friday nation top archaeologist reuters',
#  204: 'keith olbermann join current tv report keith olbermann controversial liberal pundit ho',
#  205: 'press pakistan president free american islamabad ambassador lukewilliamss',
#  206: 'cutler company sideline rahm emanuel booted chicago ballot court',
#  207: 'az sheriff armed conflict cartel inevitable lt alarmist mexico border',
#  208: 'judge rules health care law foxnews',
#  209: 'article darkpolitricks federal judge rule health care law darkpolitricks',
#  210: 'msnbc keith olbermann host al gore current tv msnbc host keith',
#  211: 'rite long ago good',
#  212: 'extreme weather australian climate expert xinhua',
#  213: 'slow news day chicago ll live mayoral debate cdt',
#  214: 'nyt news alert federal judge florida strikes obama health care law pic',
#  215: 'toyota recall car globally japanese car manufacturer toyota recall vehicle wor',
#  216: 'heard version white stripes nation army pretty',
#  217: 'alternative energy sources',
#  218: 'beef taco bell meat beef',
#  219: 'eco data initial jobless claims fall week',
#  220: 'australian disaster linked global warming',
#  221: 'blue white stripes',
#  222: 'solar energy future surpassing coal nuclear power solar energy growing united state',
#  223: 'stuff zephyr crew hacking android katy android',
#  224: 'mp launches phone hacking legal action mp will pursue legal action reporter',
#  225: 'clinton voices support mexico trip democratic underground reporting mexico city',
#  226: 'alert lawsuit bogus filled completely inaccurate fact taco bell president inaccurate fact slip',
#  227: 'countdown illinois supreme court voted unanimously rahm emanuel',
#  228: 'official pakistan face murder charge ap',
#  229: 'lawsuit taco bell meat discourage enjoying colon cancer',
#  230: 'tsa roll revealing airport scanner afp',
#  231: 'fok news keith olbermann cable news network',
#  232: 'black commented blog post eww eating lawsuit alleges taco bell beef',
#  233: 'taco bell meat post',
#  234: 'rite today stephen excellent movie',
#  235: 'destroy fire fighter van protester museum close ndp',
#  236: 'white stripes man fucking suck',
#  237: 'ill high court emanuel chicago mayor',
#  238: 'athletes prepare winter games winter games main special olympics competition event',
#  239: 'judge strike healthcare reform law conspiracy',
#  240: 'power problem suspend nj transit service northeast corridor north jersey coast jennifer brown',
#  241: 'hear interview matt baglio journalist author book rite lt plan movie',
#  242: 'amtrak nj senator propose hudson rail tunnel',
#  243: 'toyota recall involves lexus models',
#  244: 'police launch inquiry phone hacking reuters jan pm est mu',
#  245: 'oil sunday train going attack amtrak',
#  246: 'pot firing catapult arizona mexico border ap',
#  247: 'ohio unemployment families suffering',
#  248: 'surprised hear news phone hacking involves person',
#  249: 'winning future aka wtf unemployment january tcot',
#  250: 'nfl super bowl seat fiasco',
#  251: 'joe buck seat couldn super bowl',
#  252: 'monster storm brings climate blame',
#  253: 'seat ready super bowl fan cowboys stadium arlington texas nfl announced',
#  254: 'bachmann response state union cnn political ticker cnn blogs',
#  255: 'nazi germany increasingly internal passport satisfy',
#  256: 'record snowstorm global warming',
#  257: 'taco bell reveals secret beef recipe suing fox news latino',
#  258: 'rite safe horror film devil time plain dealer',
#  259: 'jobless claim pushed higher wintry weather number people applying unemployment benefit rose sharpl',
#  260: 'bag hot algore global warming wet dream match hell tcot',
#  261: 'toyota recalls vehicles quality issues',
#  262: 'mexico hit man linked acapulco death caught ap ap mexican official nabbed alleged',
#  263: 'nobel peace prize wikileaks',
#  264: 'guess cycle global warming started earlier scientist thought',
#  265: 'economy feel kid ny times article impact ohio family unemployment',
#  266: 'jobs wrong places memo president dear president state union add',
#  267: 'dtn hollywood rite win box office oscar film bump ap ap anthony hopkins horror film',
#  268: 'alabama law firm claim tacobell beef meet min govt label beef suit claim meat',
#  269: 'hillary clinton flagged judicial reform essential mexico drug war',
#  270: 'yr ago today headline panic toyota owner sticking throttle spark recall week',
#  271: 'official face murder rap pakistan fury grows',
#  272: 'murder accused diplomat spy report',
#  273: 'trial photo audio defense fund info video arrest',
#  274: 'news toyota recall auto quality woe mount tokyo reuters toyota motor corp wou',
#  275: 'toyota announces recall denver post tokyo toyota recalling vehicle worldwide',
#  276: 'embassy staffer charged pakistan',
#  277: 'don ve train crawley time',
#  278: 'taco bell beef lawsuit public ap ap taco bell legal beef meat',
#  279: 'coming airport modesty change',
#  280: 'pelosi unemployment percent prevented depression',
#  281: 'pakistani shooting case tied isi',
#  282: 'opinion taco bell suit exposes ignorance meat shortly news taco bell lawsuit ou',
#  283: 'reuters nfl invite seat fan super bowl sb',
#  284: 'overload news pakistan court extends detention diplomat reuters dawn court extends',
#  285: 'rite strings attached top honor weekend box office',
#  286: 'installing photovoltaic',
#  287: 'blog dhs tsa increase security risk',
#  288: 'anthony hopkins takes rite top box office',
#  289: 'white house pursue health care appeal judge rejects entire law yahoo finance',
#  290: 'watched therite sister pretty crazy movie',
#  291: 'forward tsa screening haven laid couple week',
#  292: 'taco bell humor social media dig beef scandal',
#  293: 'spy politicians british aide prime minister resigns',
#  294: 'updated ten myths efficient light guy',
#  295: 'kickoff loom worker scurry finalize cowboys stadium three hour kickoff cowboys stadium',
#  296: 'installing solar photovoltaic system generate electricity free energy sun',
#  297: 'clear global warming lie convince actual case',
#  298: 'listening don white stripes',
#  299: 'white stripes officially broken brb cry cuz will live',
#  300: 'polar bear swim mile day search food scientist blame global warming',
#  301: 'live tweet taco bell claims meat beef wasn',
#  302: 'will oprah reveal hollywood gossip',
#  303: 'haitian politics afraid face haiti judicial system aristide passport issue press release',
#  304: 'cabinet minister suspects hacked labour cabinet minister nick brown latest hig',
#  305: 'ticket holder denied seat fan ticket big game denied seat super',
#  306: 'will oprah reveal hollywood gossip oprah winfrey major family secret reveal',
#  307: 'rahm emanuel asks ill supreme court overturn ruling booting chicago mayoral ballot ap',
#  308: 'climate change update bizarre weather destroyed crops legendary fund manager jeremy',
#  309: 'obama call high speed rail',
#  310: 'watched solid acting anthony hopkins sr beauty alice rite view',
#  311: 'displaced nfl super bowl fan offered free nascar ticket examiner',
#  312: 'standing platform waiting delayed train friday night delay worst kind',
#  313: 'lirr service experiencing delay minute jamaica earlier train equipment problem',
#  314: 'investigation link electronic throttle unintended acceleration toyota vehicle',
#  315: 'jobless claims weeks average jan higher december week average farm jobs',
#  316: 'calls pakistan release diplomat called release american',
#  317: 'record player imma order band white stripe',
#  318: 'hillary clinton flagged judicial reform essential mexico drug war central america',
#  319: 'polar bear swim mile day search food scientist blame global warming sad story',
#  320: 'ny gov cuomo budget albany thing control',
#  321: 'good story gt captured decade mayhem mexico city photography mexico',
#  322: 'rahm emanuel supreme court case decision mayoral coming chicago chicago election',
#  323: 'rioters destroy mummy egyptian museum cairo filed arts culture history learning',
#  324: 'taco bell sued calling mixture lt beef seasoned beef sound saved lot cow',
#  325: 'gordon brown feared voicemail hacking british prime minister gordon brown wrote police summe',
#  326: 'toyota adopts devil advocate quest restore confidence brand',
#  327: 'state union unemployed american response jobless er',
#  328: 'looters destroy mummy egyptian museum',
#  329: 'major cut bbc service bbc service close language service',
#  330: 'arlington texas ap nfl super bowl fan wound seat',
#  331: 'suit taco bell beef california woman suing taco bell false advertising claiming tha',
#  332: 'regular folks united responds ruling obamacare tcot hcr',
#  333: 'al jazeera thousands egyptian youth form human shield protect egyptian museum museum egypt jan',
#  334: 'obama state union address video ve early read reaction obama state',
#  335: 'super bowl blog crews busy clearing snow ice stadium roof',
#  336: 'jesse body tsa ventura strikes lawsuit tsa',
#  337: 'rite movie review horror movie claiming inspired true event including horror',
#  338: 'train service resumed regular service time',
#  339: 'droughts floods food',
#  340: 'bbc cut job cut online budget bbc will cut job close website',
#  341: 'jus rite damn sunday',
#  342: 'facts solar energy solar energy facts turned green',
#  343: 'gov release finding toyota investigation seattle times',
#  344: 'tsa introduces generic body images video',
#  345: 'hey man will man gt border security confiscate weed tossing catapult',
#  346: 'obama state union speech yesterday energy invest tomorrow',
#  347: 'title seattle man tsa journal',
#  348: 'san luis',
#  349: 'electronic flaws toyota problems acceleration problem result',
#  350: 'optimum sports marketing blatter hint summer cup',
#  351: 'god rite slow feature ve hopkins decent',
#  352: 'rite movie clips',
#  353: 'haiti aristide passport officials haiti ready issue president jean bertrand',
#  354: 'dtn canada lawyer asks taco bell beef alabama law firm filed lawsuit claiming taco',
#  355: 'toyota recall vehicle quality woe mount',
#  356: 'mexico war drug surge lethal violence woman',
#  357: 'nobel war prize wikileaks nuke fired cablegate wikileaks assange anonymous',
#  358: 'dtn news judge strike health care law federal judge ruled presiden',
#  359: 'rite hella spooky thumb',
#  360: 'white stripe break good',
#  361: 'extreme weather sign global warming gregory connecticut average temperature',
#  362: 'gt gt toyota recall news lt lt',
#  363: 'tsa testing modest full body scanner msnbc',
#  364: 'people denied seat superbowl expected refunded time amount',
#  365: 'taco bell fight beef lawsuit ad push taco bell launching advertising campaign friday fig',
#  366: 'terrorism watch police pledge robust probe phone hacking police will leave stone terrorismwatch org',
#  367: 'egypt army secures museum pharaonic treasure report cairo reuters army unit secured egyptian mu',
#  368: 'judge rule healthcare law federal judge florida struck president barack obama',
#  369: 'climatechange high food price contributing mideast unrest climate progress',
#  370: 'trial photo audio defense fund info video arrest',
#  371: 'ft editor press risk political retribution phone hacking scandal',
#  372: 'white stripes breaking',
#  373: 'midnight showing night anthony hopkins movie rite awesome super',
#  374: 'olbermann confirms current tv job twitter lost remote olbermann confirms current tv job twitter',
#  375: 'ap illinois supreme court rahm emanuel ballot chicago mayor',
#  376: 'illinois supreme court rahm emanuel ballot',
#  377: 'obama state union speech full text prior president barack obama state union speech',
#  378: 'rite good anthony hopkins pull creepy well refer father',
#  379: 'shouldn bbc parts service',
#  380: 'latin america news mexican trafficker catapult drug border afp afp mexican drug yahoo',
#  381: 'stadium finished fan left temporary seat cowboys stadium fin',
#  382: 'post sen mary mayor mitch reax state union mention gulf',
#  383: 'judge overturn obama health care law nbc',
#  384: 'ap toyota recall vehicle fuel leak',
#  385: 'taco bell responds meat lawsuit globe mail',
#  386: 'telling social web state union stats',
#  387: 'american diplomat charged double murder pakistan called drone',
#  388: 'haiti issues passport leader aristide port au prince haitian government commondreams org',
#  389: 'donald rumsfeld reflects writing memoir ap news',
#  390: 'village school officials tax cap budget cuts',
#  391: 'court rules rahm emanuel ineligible mayor chicago opponents white house',
#  392: 'taco bell fight beef lawsuit taco bell launching advertising campaign today fight',
#  393: 'rahm stay chi mayoral ballot dbl standard city residency rule public worker nytimes',
#  394: 'king speech expands theater film news rite mechanic box office entry des',
#  395: 'taco bell meat law firm claim lawsuit taco bell false advertising refers',
#  396: 'illinois court emanuel stay chicago ballot chicago reuters white house chief st news',
#  397: 'super bowl ticket holder seat cowboys stadium nfl',
#  398: 'toyota recall lexus gs vehicle detroit news',
#  399: 'jerry jones issue super bowl xlv statement',
#  400: 'npr news ill high court emanuel chicago mayor',
#  401: 'tsa starts testing scanners don naked body despite protest tsa ther',
#  402: 'qatar fifa cup stadiums',
#  403: 'rahm emanuel hit chicago roadblock',
#  404: 'fans denied access seat super bowl superbowl steelers cowboys suck',
#  405: 'green tips',
#  406: 'cold global warming big deal',
#  407: 'bbc news clegg denies coulson exit damage nick clegg denies government damaged impending',
#  408: 'federal judge fla rule health care plan live better',
#  409: 'california resident sue taco bell false advertising chris lawsuit filed federal court',
#  410: 'keith will ko current tv keith extremely role progressive ideal fok',
#  411: 'cnn jesse ventura slam tsa lawsuit count jesse ventura flier don junk touched',
#  412: 'latest news jesse ventura force tsa submission jennifer things pr guardian usa',
#  413: 'rite movie alright',
#  414: 'toyota recalls vehicles fuel',
#  415: 'judge rule obama health care law',
#  416: 'emanuel seeks ruling chicago race rahm emanuel president barack obama fb',
#  417: 'illinois high court review emanuel case illinois supreme court agreed review case challenging',
#  418: 'breaking rahm emanuel file motion stay illinois appellate court ruling illinois supreme court will file appeal court tues',
#  419: 'suspends talk threatens cut aid pak united states suspended high level dialogue pak',
#  420: 'polar bear swim day searching sea ice stinking global warming',
#  421: 'rahm emanuel booted ballot appellate court decision',
#  422: 'toyota nightmare vehicle recalled worldwide',
#  423: 'feds toyota problems electric cars nasa reviewed code',
#  424: 'rahm emanuel chicago ballot news',
#  425: 'tb meat beef taco bell suing terra',
#  426: 'toyotas recalled fuel leak fear toyota recalling vehicle japan abc news',
#  427: 'breakingnews looters broke museum destroyed pharaonic mummy late friday nation top archaeologist reuters egypt',
#  428: 'check film foot fence mexico border dvd',
#  429: 'holy smoke consular employee shot pakistani consular van hit kill motorcyclist lahore',
#  430: 'countdown keith olbermann will launch hour long current tv spring',
#  431: 'rite tops friday night box office',
#  432: 'positive productive idea obama state union gop support tcot sgp',
#  433: 'mexican smugglers catapult pot border yahoo news',
#  434: 'dtn pakistan wife pakistani man shot diplomat commits suicide pakistani nurse rela',
#  435: 'anthony hopkins rite tops friday box office hollywood reporter',
#  436: 'court toss emanuel chicago mayoral ballot reuters',
#  437: 'andy gray suing notw fired sky footage smell murdoch',
#  438: 'headline release final report toyota recalls today obama administration mont',
#  439: 'amtrak boston ny late rolling',
#  440: 'chevrolet volt nissan leaf three finalist north american car year',
#  441: 'court rule rahm emanuel removed chicago mayoral ballot meet residency requirement',
#  442: 'toyota recalling vehicle',
#  443: 'jan fire spreading close egyptian museum report clash police soldier',
#  444: 'star kubica involved serious crash yahoo eurosport',
#  445: 'source uk leader feared hacked british prime minister gordon brown wrote police summ',
#  446: 'judge strikes obama health care overhaul federal judge ruled monday president',
#  447: 'bbc service ax language job afp afp bbc service wednesday',
#  448: 'museum',
#  449: 'movie review rite anthony hopkins rite photo warner bros left explore',
#  450: 'oprah big secret sister child betting state reunion state union',
#  451: 'musings live blogging state union address watch state union',
#  452: 'woot rahm emanuel chicago mayor ballot fb',
#  453: 'illinois supreme court rahm chicago resident eligible mayor examiner illinois illinois',
#  454: 'fox news report emanuel booted mayor ballet appellate court small country',
#  455: 'jobless claim tumble week reuters reuters claim unemployment benefit dr',
#  456: 'robert paisola news taco bell beef lawsuit public ap ap taco bell news zone',
#  457: 'athletes compete celebrate special olympics michigan state winter games jordan february',
#  458: 'study ii watch nsa service',
#  459: 'florida judge strike obamacare mandate full decision word day vo',
#  460: 'high unemployment flint detroit forbes list miserable high foreclosure rate',
#  461: 'american missionary shot killed flee gunman mexico police fb',
#  462: 'solar water heating cut energy bill carbon',
#  463: 'movies anthony hopkins weekend box office rite rite top spot',
#  464: 'bbc cut online budget cutting website job year',
#  465: 'war drug lost drug justice health lie',
#  466: 'cnet future uncertain energy dashboard',
#  467: 'will social medium damage control rescue taco bell',
#  468: 'fell love white stripes load time meg will greatest muse',
#  469: 'white stripes split meg porn career',
#  470: 'probe clear toyota electronic throttle washington reuters government probe cleared toyota motor corp electronics caus',
#  471: 'dtn usa taco bell face question meat alabama law firm claim lawsuit taco bell',
#  472: 'suing taco bell takes beef gate',
#  473: 'keith land greetings keith olbermann chief news officer current media awayyyyyy fok',
#  474: 'ibd rahm resident evil emanuel comparison serving soldier chicago llinois tcot tpp',
#  475: 'meat sold taco bell restaurant doesnt meet minimum requirement set labeled beef',
#  476: 'pakistani judge order american held day lahore pakistan court thursday ordered',
#  477: 'breaking news patriotic breaking pedal toyota works space nasa',
#  478: 'bbc news bbc craig oliver replacing andy coulson',
#  479: 'court allows emanuel ballot chicago mayor nytimes tlot news illinois dems',
#  480: 'absolutely devastated white stripes',
#  481: 'haiti issue passport leader aristide haitian government issued passport pres',
#  482: 'duvalier return haiti aristide america media',
#  483: 'displaced fan super bowl tix year fans displaced seat damage sunday cowboys',
#  484: 'drug catapult mexico border drug catapult mexico foxnews',
#  485: 'fewer people applied unemployment benefit week jp',
#  486: 'injury major setback assault title year reserve driver will struggle pt',
#  487: 'toyota recall noah model japan',
#  488: 'plan hearing fare policy change',
#  489: 'dtn pakistan faheem wife death tragedy washington united states monday called suicide',
#  490: 'tonight cyclone supposed hit australia live cyclone thursday damn global warming sucks',
#  491: 'lawsuit taco bell beef',
#  492: 'court rahm emanuel ineligible mayor',
#  493: 'florida district court judge ruled obamacare',
#  494: 'judge ruling health reform law radical judicial activism overturned medi',
#  495: 'lawsuit taco bell ground beef meat filling',
#  496: 'extreme weather create global food crisis joseph romm',
#  497: 'official call release american',
#  498: 'harman police investigate phone hacking allegation',
#  499: 'youtube video white stripes nation army',
#  500: 'official face murder charge pakistan',
#  501: 'people expect real food taco bell filed class suit',
#  502: 'nfl cowboys stadium drop ball temporary seat canadian press arlington texas set',
#  503: 'small business taco bell mystery meat lawsuit lesson',
#  504: 'fan tix super bowl seat fire marshall temp seat safe triple face refund',
#  505: 'foray foreign friday mexican catapult adventures',
#  506: 'times detroit auto chrysler stay',
#  507: 'tsa unveils generic body scan ben usa today transportation security administration began',
#  508: 'blue special olympics alpine team success prov winter games well team',
#  509: 'post tsa facing lawsuit governor ventura big sis fascism tsa',
#  510: 'affordable care florida federal judge hcr obamacare tcot tlot',
#  511: 'energy conservation tips south hills electric heating cooling',
#  512: 'judge entire law piper',
#  513: 'taco bell meat beef',
#  514: 'chauffeur guy suddenly feel better imminent demise service',
#  515: 'white stripe broke dont ill live',
#  516: 'experts start consultation status davis',
#  517: 'haiti awaits vote aristide backer protest reuters share friends news top stories news news',
#  518: 'quot rite quot lead oscar fueled box office reuters',
#  519: 'cuomo york state budget news buffalo presenting proposed state',
#  520: 'bbc service cuts hundreds jobs sky news google news uk uk news grant buzzbox',
#  521: 'unconditional release davis pakistan pakistan opinion',
#  522: 'fear loathing britain true globalpost phonehacking',
#  523: 'illinois state appeals court declared rahm emanuel ineligible mayor chicago born kenya',
#  524: 'dear keith olbermann gig revealed chief news officer current media mediaite',
#  525: 'jobless claim surge week washington reuters claim unemployment benefit rose mor',
#  526: 'rite pretty serious movie watch',
#  527: 'nano bio nanotechnology full funding cuomo budget amid cut',
#  528: 'terrific abc news story role climate change play extreme winter weather',
#  529: 'toyota recall',
#  530: 'bank robbed light electricity phone internet cabinet member fleeing protester dying egypt',
#  531: 'watch rite free movie online movies online',
#  532: 'book news illinois rahm ballot',
#  533: 'rite captures friday box office thriller anthony hopkins mart',
#  534: 'hurt critically ice falling super bowl stadium super bowl official injured hit',
#  535: 'toyota recall vehicle worldwide toyota recalling vehicle',
#  536: 'goo qatar unveils sustainable stadiums cup inhabitat green design will save',
#  537: 'suit questions beef content taco bell products',
#  538: 'pakistan court refuse release official denying immunity',
#  539: 'drug catapult mexico border',
#  540: 'illinois high court order emanuel ballot',
#  541: 'gonna fight em',
#  542: 'anthony hopkins takes rite top box office',
#  543: 'rahm loses worse bears appellate court rule chicago mayoral ballot',
#  544: 'florida court strike obama healthcare reform law times india daily mail florida',
#  545: 'court prior ruling rahm ballot chicago',
#  546: 'taco bell product real beef lawsuit',
#  547: 'news emanuel appeal ruling booting ballot',
#  548: 'super bowl fan seat unsafe',
#  549: 'winter',
#  550: 'taco bell beef taco beef lawsuit share info',
#  551: 'toyota denies problem car recall driver fault insurance company sue couldn pay drive',
#  552: 'government finding toyota electronics released today',
#  553: 'charlotte douglas airport boy security measure ahead patent machine',
#  554: 'cost cent expecting tacobell defends beef secret recipe',
#  555: 'fox friends hosted meteorologist climate joe bastardi cast doubt tcot medium',
#  556: 'mta york city transit mta bus suspended service city road weather',
#  557: 'thomas tank engine cash plane obama call high speed rail',
#  558: 'court toss emanuel chicago mayoral ballot',
#  559: 'quarter bbc service staff uk foreign office grant reduction',
#  560: 'msnbc host keith olbermann head current tv ap ap keith olbermann news entertainment',
#  561: 'expert warns global warming will lead colder climategate lol',
#  562: 'chicago sun times report appeal court ruled emanuel meet residency require',
#  563: 'nist appoints senior advisor press release',
#  564: 'star ledger weather toll weary commuter thousands power train resume normal service',
#  565: 'clinton mexico drug war',
#  566: 'killed mexico shootout border',
#  567: 'learn seal winter dukes stuff',
#  568: 'release finding toyota sudden acceleration probe',
#  569: 'thousands egyptians form human chain egypt museum protect looting aljazeera',
#  570: 'taco bell sued meat actual meat surprised high',
#  571: 'bbc reporter told thanked jewish people paris service role ww',
#  572: 'business billion plan bring high speed rail secret cou',
#  573: 'greetings controversy kidding friend tsa teach busi',
#  574: 'displaced super bowl xlv fan super bowl xlvi ticket story',
#  575: 'displaced fan will receive free super bowl ticket year coupon book nfl',
#  576: 'topstories amtrak senator ny nj rail tunnel plan reuters share friends top news',
#  577: 'government electronic flaws toyotas obama administration investigation',
#  578: 'fox illinois supreme court order chicago mayoral ballot include rahm emanuel appeal',
#  579: 'fans robbed xlv gt nfl offering triple money refund super bowl fan seat well didn exist',
#  580: 'white stripes breaking despite joke rolling kinda blue',
#  581: 'arlington texas ap super bowl official hurt critically ice falling cowboys stadium',
#  582: 'st press screening year rite wednesday low expectation disappointed',
#  583: 'unemployment clt region drop',
#  584: 'press pakistan president free american ap ap ambassador pakistan preside',
#  585: 'unemployment claims dip job growth',
#  586: 'ain beef taco bell burrito lawsuit chain label taco meat filling',
#  587: 'olbermann going al gore current tv big step nice career move tcot',
#  588: 'climate change aka global warming real deny extreme weather worldwide proof',
#  589: 'judge strike healthcare reform law',
#  590: 'independent medium ftw msnbc host keith olbermann head current tv',
#  591: 'story auto',
#  592: 'energy efficient window great save heat winter',
#  593: 'ingredients taco bell meat mysterious',
#  594: 'knoxville unemployment rates unemployment rate december percent',
#  595: 'pakistan walk raymond davis case hmm thought going',
#  596: 'tomorrow nsa national business park expo',
#  597: 'rip white stripes',
#  598: 'unemployment rise state fall ap ap unemployment rate rose hawaii alohatone',
#  599: 'link didn copy taco bell lawsuit',
#  600: 'automatic earth january working age americans full time job',
#  601: 'keith olbermann host news commentary current tv news produced corporate',
#  602: 'global warming idk man',
#  603: 'photo movie trailers rite trailer video hulu watch stream',
#  604: 'uk phone hacking probe spread acting head metropolitan police face question',
#  605: 'editorial high court protect voter press illinois supreme court ordered chicago',
#  606: 'fan air save heating cooling cost fan reduce summer air energy cost',
#  607: 'tsa testing body scanning system traveler pass scanner computer',
#  608: 'movie news channel box office anthony hopkins rite stuff friday movies',
#  609: 'post nfl knew week seat problem ap',
#  610: 'official pakistan face murder charge pakistan will pursue murder charge consular emplo',
#  611: 'republicans propose deep cut funding wide range target pbs amtrak',
#  612: 'governor budget idea democrats republicans budget includes idea',
#  613: 'court kick rahm emanuel chicago mayoral ballot guess leaving white house wasn good idea',
#  614: 'making energy efficient winter months',
#  615: 'diplomatic worker face murder charge pakistan shooting los angeles times',
#  616: 'fox global warming fails miserably care news network',
#  617: 'anthony hopkins rite knock strings attached cinema movie trailer ri',
#  618: 'falling work force jobless dip',
#  619: 'great idea hack nfl hopes replace ipads',
#  620: 'cuomo cuts spending budget plan',
#  621: 'mutilated bodies discovered mexico',
#  622: 'statement bbc service ahead staff briefing detail bbcworldservice',
#  623: 'illinois supreme court halt printing ballot rahm emanuel illinois supreme court chicago',
#  624: 'yesssss breaking il supreme court rule rahm emanuel will ballot',
#  625: 'unemployment rates state glance ap ap unemployment rate rose state month fresh',
#  626: 'jobless claim tumble week washington reuters claim unemployment benefit dropped expected',
#  627: 'unemployment claim drop',
#  628: 'david cameron fears phone hacked hmmmm funny wonder',
#  629: 'initial probe report davis case presented court sunny',
#  630: 'keith olbermann current tv nyt news keith newest keith olbermann',
#  631: 'extreme weather create global food crisis joseph romm',
#  632: 'anthony hopkins takes rite top box office',
#  633: 'obama face sputnik moment declaring nation face big decision confronted',
#  634: 'comment emanuel ballot access rahm emanuel stay ballot illinois supreme cou',
#  635: 'sports digest fifa discus moving cup qatar summer winter san jose fifa',
#  636: 'taco bell answer lawsuit beef',
#  637: 'security built tsa touch junk will bust left side face tcot',
#  638: 'ill high court emanuel chicago mayor ap',
#  639: 'll white stripes',
#  640: 'find defect toyota electronic throttle',
#  641: 'obama nation google facebook american innovation state union',
#  642: 'al gore explains global warming matt global warming guru vice',
#  643: 'msnbc host keith olbermann head current tv congrats current',
#  644: 'nfl fan ticket seat scofflaw weren seat tickets superbowl',
#  645: 'met police reopen investigation phone hacking news ian sacked',
#  646: 'wisconsin performed pretty well recession true unemployment avg',
#  647: 'oprah family secret news views news literally shook heart time',
#  648: 'source uk leader feared hacked',
#  649: 'gun raid cartel work arizona',
#  650: 'ill court throw emanuel chicago ballot ap ap day ago rahm emanuel',
#  651: 'judge strike obama healthcare law reuters',
#  652: 'update lt gov seek support cuomo budget',
#  653: 'keith olbermann headed current tv report msnbc top msnbc headline msnbc anchor keith',
#  654: 'haiti allows president aristide return haitian politics interesting',
#  655: 'bbc service ax language service',
#  656: 'billion plan bring high speed rail',
#  657: 'oprah blockbuster announcement monday',
#  658: 'toyota recall cars worldwide fuel issues abc news',
#  659: 'well surprise good thing healthcare law declared',
#  660: 'judge strike healthcare reform law law men',
#  661: 'vinson rule entire hcr law lack clause entire text',
#  662: 'player report nfl invite fan lost seat super bowl washington post',
#  663: 'cuomo proposes deep cut suny cuny shameful',
#  664: 'emanuel ruling ll prevail roberto joined dozen supporter rally',
#  665: 'travel historic blizzard devastating air land travel',
#  666: 'blatter expects stay summer updates fifa president sepp blatter changed monday',
#  667: 'dead fish plan appeal court ruling removed chitown mayoral ballot fb',
#  668: 'drug smuggler second pot catapult',
#  669: 'heritage morning bell victory road repeal teaparty hcr',
#  670: 'taco bell percent real beef lawsuit claim',
#  671: 'obama health care overhaul ruled',
#  672: 'poll find oppose airport security measure money company los angeles times',
#  673: 'unemployment hits harder youth united states',
#  674: 'recalling toyota',
#  675: 'watchdog group question google relationship nsa community',
#  676: 'government electronic flaw toyotas ap',
#  677: 'rahm emanuel stays ballot chicago mayoral election filed news politics president obama ra',
#  678: 'extreme weather create global food crisis joseph romm',
#  679: 'global drama coming month drug ir major haiti aristide passport',
#  680: 'riding amtrak auto train tweet bad faster comfortable good food',
#  681: 'national guard finds pot firing catapult',
#  682: 'truth stand pakistanis killed diplomat david gt pl read comment',
#  683: 'toyota recall car cnn',
#  684: 'taco bell beef isn meat horror',
#  685: 'final numbers detroit auto bigger',
#  686: 'rahm emanuel chicago ballot news',
#  687: 'met fresh phone hacking probe police launch fresh investigation phone hacking receiving',
#  688: 'teams splash special olympics special olympics louisiana',
#  689: 'governor cuomo brought detail proposed budget today will painful',
#  690: 'rite amazing happy month love lt',
#  691: 'rite great great cast story',
#  692: 'amtrak gt sea min late europe china kick ass',
#  693: 'ut knoxville chancellor jimmy cheek issue ambitious goal reduce campus energy',
#  694: 'unemployment record american consumer news',
#  695: 'usa catapult drug drug smuggler marijuana arizona mexico',
#  696: 'supreme court agrees hear appeal decision knock rahm ballot chicago sun times',
#  697: 'asks pakistan release diplomat india news',
#  698: 'ten york city hospitals close governor cuomo proposed medicaid cuts',
#  699: 'will severe amazon drought affect rate global climate change',
#  700: 'lawsuit claim taco bell meat mixture percent beef change opinion food',
#  701: 'reward long service staff times',
#  702: 'taco bell law firm suing',
#  703: 'jobless claim tumble week washington reuters claim unemployment benefit dropped',
#  704: 'rite tops box office mechanic takes third jared',
#  705: 'court emanuel eligible chicago mayor',
#  706: 'taco bell fights ad campaign',
#  707: 'parent kid hospitals school arm cuomo budget union decry layoff warning',
#  708: 'hmm cnn reported economy gained job jan ppl street suez egypt figure outsource',
#  709: 'court halts chicago emanuel',
#  710: 'dtn news raymond davis released raymond davis american national killed',
#  711: 'ready call action call invest future create job country sotu',
#  712: 'ill court throw emanuel chicago ballot',
#  713: 'clear toyota electronics investigation toyota safety problem find electronic flaw',
#  714: 'sad white stripes split steam side project best moment',
#  715: 'health care law deemed illegal news press health care law deemed illegal news',
#  716: 'pot firing catapult arizona mexico border',
#  717: 'awesome business article global warming crazy stuff tree',
#  718: 'unreal sad story fan ticket super bowl seat',
#  719: 'reports italian polish medium claim robert kubica injured rally accident italy',
#  720: 'increase oil prices beneficial solar power solar energy focus point european union',
#  721: 'jobless claim tumble week washington reuters claim unemployment benefit dropped',
#  722: 'will missionary recognize haiti haitians aristide return helpless',
#  723: 'court emanuel eligible chicago mayor ny times pa habit place',
#  724: 'report private sector job january york private employer created net',
#  725: 'major cut bbc service bbc share friends top news entertainment ne',
#  726: 'business leader governor cuomo budget',
#  727: 'power problem delay light rail train service denver power problem train storage yard',
#  728: 'web weed firing catapult discovered mexico border drugs',
# ...
#  755: 'tsa pat thunder bay airport friendly',
#  756: 'global warming left version climate wise attributed warming',
#  757: 'fo issue diplomatic card raymond davis',
#  758: 'train arrival chicago combined train train',
#  759: 'interesting report toyota study happened',
#  760: 'keith olbermann current tv perfect ll',
#  761: 'amtrak service north nyc cancelled',
#  762: 'npr topics politics',
#  763: 'global warming update bizarre weather destroyed crops',
#  764: 'davis case lhc order probe task senior cop',
#  765: 'white stripe broke feel inevitable duo gonna work commonsense',
#  766: 'white stripes broke well',
#  767: 'snow job gore channel liberal columnist proof global warming fueled blizzard gore moron',
#  768: 'stephen glover rupert murdoch lost control story coulson',
#  769: 'judge escalate battle healthcare reform',
#  770: 'growth continues surge increasing productivity',
#  771: 'taco bell fight beef lawsuit ad push',
#  772: 'updates museum situation egypt risk fire looting jan jan',
#  773: 'tho train late love amtrak vintage style poster',
#  774: 'jobless claim fall forecast market forecast fall ch',
#  775: 'bbc service will voice',
#  776: 'judge strike obama healthcare law reuters',
#  777: 'taco bell sued mystery beef ingredients',
#  778: 'taco bell beef beef updated',
#  779: 'metropolitan police pledge job properly yeah fb',
#  780: 'expect asks father lucas played anthony hopkins rite',
#  781: 'drug smugglers catapult fling pot az arizona mexico illegals tcot',
#  782: 'governor andrew cuomo softens vow work bloomberg pension cuomo sought thursday',
#  783: 'clear toyota electronics investigation toyota safety problem find electronic flaw',
#  784: 'bbc service cut politicians duh',
#  785: 'oprah winfrey revealing big family secret tomorrow oprah winfrey',
#  786: 'unemployment rates state glance',
#  787: 'demands release diplomat pakistan',
#  788: 'mechanic rite good',
#  789: 'weigh weigh day global warming climatechange',
#  790: 'embassy demand release diplomat held pakistan shooting death source latimes',
#  791: 'side tacobell lawsuit suing cast vote',
#  792: 'study links looming food supply catastrophe global warming',
#  793: 'republicans build steam health care law repeal florida republicans acting',
#  794: 'phil mocek acquitted charge tsa arrest',
#  795: 'watching rite therite',
#  796: 'bachmann state union rebuttal',
#  797: 'federal judge toss entire healthcare reform law account individual mandate acquire insurance coverage',
#  798: 'day special olympics games athens team ireland athletes will compete specialolympics athens',
#  799: 'gossip day day bbc service cut language service',
#  800: 'toyota recall car globally japanese car manufacturer toyota recall vehicle worldwide fuel leak',
#  801: 'climate change higher food prices paul krugman today nyt',
#  802: 'white stripes officially call quits',
#  803: 'supreme court will hear appeal ruling knocking emanuel ballot chicago sun times',
#  804: 'trial photo audio defense fund info video arrest',
#  805: 'guess calling beef beef gross',
#  806: 'call met phone hacking probe facing call investigate metropolitan police',
#  807: 'snubbed fans tickets super bowl offered free ticket year su',
#  808: 'amtrak senator ny nj rail tunnel plan york reuters amtrak announced plan monday',
#  809: 'lol mexican drug lord billionaire statement personally america keeping drug illegal',
#  810: 'toyota recall car fuel leak ap ap toyota recalled car',
#  811: 'unemployment ohio gov unemployment ohio gov ohio opened hiring december',
#  812: 'high speed rail amtrak horrible government high speed rail will better',
#  813: 'window covering insulation closing drape blind night help save energy heating',
#  814: 'watching rite therite',
#  815: 'embassy call release employee accused fatal shooting cnn wire staff islamabad pakis',
#  816: 'ft editor barber stick phonehacking knife murdoch publish rival wsj',
#  817: 'huge expectations unemployment adjusted',
#  818: 'huge toyota recall includes lexus gs sedans',
#  819: 'breaking news federal court rules obamacare',
#  820: 'news ireland fresh recall setback toyota toyota will recall irish news',
#  821: 'therite dumbass movie',
#  822: 'nfl confirms temporary super bowl seating inside cowboys stadium completed',
#  823: 'super bust woes texas host super bowl week texas super',
#  824: 'mexican drug smuggler catapult weed border fence remote video system captured dr',
#  825: 'nfl seating area complete chicago breaking sports',
#  826: 'taco bell social media address pr challenge',
#  827: 'estimated listener will lost service cut terrible news fave station chinese language cut',
#  828: 'fans denied access seat super bowl yahoo sports',
#  829: 'toyota recall vehicle globally reuters reuters toyota motor corp recall',
#  830: 'mexican drug smuggler catapult weed border fence',
#  831: 'reading court rahm emanuel eligible chicago mayor nytimes illinois supreme court',
#  832: 'obama economy priority generate job unemployment rate pe',
#  833: 'huffingtonpost robert strong state union address union state',
#  834: 'toyota recall vehicle globally tokyo reuters toyota motor corp recalling mor',
#  835: 'severe weather event contributing droughts floods food shortage agriculture climate',
#  836: 'forward keith olbermann current tv gig hope brings worst persons',
#  837: 'security database tools watch turning firefox ethical hacking platform',
#  838: 'don excited yr plan american access high speed rail year doubt success',
#  839: 'mashable social web state union stats presiden',
#  840: 'taco bell beef lawsuit public yahoo news',
#  841: 'read spending info',
#  842: 'thought egyptian protester hope fire destroy ton history',
#  843: 'toyota recall car including lexus model',
#  844: 'silenced cut douglas media bbc news bbc revealed full extent',
#  845: 'white house plan push energy efficient building wsj sustainability',
#  846: 'australia greatest olympian ian thorpe expected reportedly comeback international swim',
#  847: 'rahm emanuel ballot chicago alternet',
#  848: 'haitian politics rev jeremiah wright aristide return haiti will good aristide',
#  849: 'williamson tn unemployment rate dec lowest region lowest tn full report',
#  850: 'site rip white stripes',
#  851: 'sports news fifa al jazeera strike cup broadcast deal fifa qatar based broadcaster al jazeera',
#  852: 'starwatch consumer government issue report toyota recall kansas city star kansas city',
#  853: 'hey hear taco bell sued beef filling beef told good',
#  854: 'diplomat killed intelligence lahore shootout',
#  855: 'guess tsa doesn ve radiation breast cancer shame didn',
#  856: 'reading keith olbermann move tv',
#  857: 'listening nation army white stripes nowplaying',
#  858: 'save energy cash quick easy tips article will help save ton money saving en',
#  859: 'pay attention agent curtain flier beat tsa video recording charge court',
#  860: 'paul krugman blames egypt crisis global warming tcot gop sgp',
#  861: 'keith olbermann sense current tv tcot',
#  862: 'bbc slash foreign service bbc service will job announcing plan',
#  863: 'unemployed find help job search group',
#  864: 'wrapup employment gaining speed jobless rate',
#  865: 'taco bell lawsuit claims chain beef meat',
#  866: 'baby doc haiti help aristide supporter return rebuild factor',
#  867: 'cuomo expose dirty budget trick cut announced today',
#  868: 'local politician react president obama state union address',
#  869: 'taco bell fight beef charge truth ad',
#  870: 'displaced fans will receive free super bowl tickets year',
#  871: 'phone hacking gordon brown called police fear mobile phone message intercepted gordon bro',
#  872: 'government electronic flaw toyota acceleration case',
#  873: 'obama touts improving economy proves living dem dream american unemployed increases real nightmare',
#  874: 'limited train service',
#  875: 'toyota recall car globally japanese car manufacturer toyota recall vehicle wor',
#  876: 'white stripes broken cant care',
#  877: 'gr news current greetings frm keith olbermann chief news officer current media',
#  878: 'unemployment benefit snow',
#  879: 'ap headlines government electronic flaw toyotas washington ap obama administration',
#  880: 'toyota recalls vehicles',
#  881: 'rule law doesn apply valerie potus belief rahm eligible mayor disagrees appeal court',
#  882: 'january job report winter weather job january yea',
#  883: 'news cuomo find secret budget flaw albany',
#  884: 'tk white stripes dead tk',
#  885: 'pm brown feared voice mail hacking amid scandal source',
#  886: 'jesse ventura slam tsa lawsuit count jesse ventura flier don junk touched tr',
#  887: 'hudson tunnel amtrak high speed pitch',
#  888: 'battle exorcism movie rite exorcism hmmm read find care weigh',
#  889: 'hacking case war tabloids york times',
#  890: 'easier save energy offer steam setting remove',
#  891: 'snow continue northeast grounded cnn',
#  892: 'judge rule healthcare reform reuters reuters judge florida monday',
#  893: 'tune fox news channel ct today debate lawsuit taco bell',
#  894: 'amtrak california zephyr today',
#  895: 'mexican drug dealers catapult transport drugs border',
#  896: 'phil mocek beat tsa court civil liberty hero great news bad news tsa bully',
#  897: 'monster snowstorm spell global warming cnn',
#  898: 'fact mm unemployed mm didn hear gov night',
#  899: 'obama call high speed rail',
#  900: 'florida health care court decision apply mandatory auto insurance',
#  901: 'federal judge florida strike obama health care plan south florida',
#  902: 'taco bell meat center class action lawsuit',
#  903: 'pakistan court extends detention diplomat msnbc',
#  904: 'federal judge rules health care law violates constitution',
#  905: 'melting sea ice force polar bear swim day climate change environment',
#  906: 'white stripes broke bummer',
#  907: 'bye bye system ultra simple energy saving bye bye system collection device',
#  908: 'alabama law firm taco bell beef',
#  909: 'fifa resist change cup cup south',
#  910: 'nist report aim help agency deploy cloud apps ease cloud computing service',
#  911: 'state heartbreaking face barack conservative obama job proposal tcot',
#  912: 'oprah winfrey promise reveal hidden family secret pop',
#  913: 'three continent bbc service cutback media guardian',
#  914: 'film rite based training real priest film faith catholic exorcist',
#  915: 'issue dallas stadium superbowl fan seat unsafe',
#  916: 'favorited youtube video ventura lawsuit tsa pat downs unlawful sex',
#  917: 'teepeecreek plan billion passenger rail biden teepeecreek',
#  918: 'vote cruise cancelling call mexico visit mexico',
#  919: 'breaking news federal judge florida strike obama administration healthcare law',
#  920: 'haitian politics rev jeremiah wright aristide return haiti truth',
#  921: 'florida judge rule congress authority require americans buy health insurance hcr obamacare teaparty tcot',
#  922: 'coming nonfarm payroll jobless rate january coming nonfarm payroll',
#  923: 'tcot type rahm emanuel booted chicago mayoral ballot thx il supreme court',
#  924: 'good rahm',
#  925: 'cnn football official apologizing ticket holding fan denied seat sunday super bowl',
#  926: 'hint fake meat real taco bell scandal better',
#  927: 'toyota recalls cars worldwide fuel sensors safety recall inspect installation fu',
#  928: 'florida judge voids health reform law second federal judge ruled monday',
#  929: 'governors state job chopping block will lot state worker joining unemployment',
#  930: 'nation army white stripes',
#  931: 'court emanuel mayor',
#  932: 'pakistan high court block release official exit control list islamabad ruling mov',
#  933: 'data point strong growth momentum jobless claim tumble productivity rise feb pm',
#  934: 'happy drug catapult mexican border',
#  935: 'ill court throw emanuel chicago ballot',
#  936: 'cuomo budget cuts spending schools medicaid gov andrew cuomo tuesday proposed billion',
#  937: 'knew soy taco law firm sue taco bell claim beef label misleading',
#  938: 'keith olbermann current tv hosting chief news officer',
#  939: 'judge strike healthcare reform law',
#  940: 'judge rule health care law mark arsenault washington federal judge florida',
#  941: 'electronic flaws toyota problems',
#  942: 'flood uk phone hacking scandal subsided',
#  943: 'mexican smuggler catapult send illegal drug border millions americans',
#  944: 'news videos white stripes call quits read breakup rip bummer',
#  945: 'time unemployment claim fall',
#  946: 'cold climate change caused global warming severe weather pattern stay warm bro',
#  947: 'oprah winfrey family secret prompt buzz',
#  948: 'unveils billion high speed rail plan',
#  949: 'ohio unemployment rate decline pres hu midwest visit catalyst',
#  950: 'amtrak warns limited ne corridor tomorrow storm eco terrorism',
#  951: 'best superbowl moment people paid ticket forced stand front unfinished seat',
#  952: 'good second second coming aristide',
#  953: 'dtn news accused diplomat hold special privilege lahore deputy prosecutor general punjab',
#  954: 'movie review rite mill exorcist movie news usa review rite',
#  955: 'newsmax politics ill high court mulls rahm emanuel mayoral uknews news',
#  956: 'demand release diplomat killed united states demanded release amer',
#  957: 'robert paisola news toyota recall vehicle fuel leak toyota recall mi',
#  958: 'health care law struck',
#  959: 'phone hacking select cttee time indy coulson',
#  960: 'tsa testing advanced imaging technology story atlanta tsa tuesday testing',
#  961: 'hillary clinton flagged judicial reform essential mexico drug war year overhaul',
#  962: 'hacking phone law crime',
#  963: 'american representative demand release raymond davis currently held pakistan prime suspect double',
#  964: 'darn il supreme court rule printing ballot emanuel',
#  965: 'dems gop dropped job focus',
#  966: 'taco bell beef convenience cost',
#  967: 'toyota recall car concern',
#  968: 'health care overhaul law ruled implementation law will will',
#  969: 'rahm emanuel victim chicago style politics thrown mayoral ballot',
#  970: 'official raymond davis lahore murder charge',
#  971: 'court rule rahm emanuel ineligible chicago mayoral race law il chicago rahm',
#  972: 'budget cuts created equal ceo donald trump hospital',
#  973: 'tsa test privacy enhancing software body scanner privacy',
#  974: 'power energy pc',
#  975: 'nursing bed paul krugman blames egypt crisis global warming',
#  976: 'cuomo budget reading quick takeaway doesn recommend closing',
#  977: 'lahore lahore high court lhc chief justice tuesday blocked move hand authority',
#  978: 'tsa agent work finger hiding special yesss',
#  979: 'olbermann join al gore current tv ny times reports',
#  980: 'entertainment msnbc host keith olbermann head current tv ap ap keith olbermann mo',
#  981: 'pressure kills pakistani victim agent raymond davis',
#  982: 'rahm chicago economy raised tax deserve',
#  983: 'movie knew devil lmao therite',
#  984: 'taco bell class action suit taco meat beef taco bell sued false advertising',
#  985: 'cuomo budget cut spending time mid',
#  986: 'buddy david australia sends joe bastardi report coming ice age',
#  987: 'dynamic chilling big time optimum energy making mark managing cooling system large',
#  988: 'buck unemployment trend',
#  989: 'pakistan relation strained cia agent held court shooting embassy raymond davis',
#  990: 'court toss emanuel chicago mayoral ballot illinois state appeal court monday threw illinois il',
#  991: 'weekend subway service disruptions thursday snowstorm forced metropolitan tran',
#  992: 'probe clear toyota electronic throttle',
#  993: 'haiti issue passport president jean bertrand aristide enabling exile',
#  994: 'toyota announces global recall vehicle fuel leak',
#  995: 'best ways save energy live energy efficient save mo',
#  996: 'future uncertain energy dashboard transmission improve efficiency typically muc',
#  997: 'nist issues cloud security guidelines government standard body launched wiki feedback',
#  998: 'proposed house budget proposes massive cut transit amtrak high speed rail congress',
#  999: 'il supreme court rule rahm emanuel ballot chicago mayor guy',
#  1000: 'judge ruled health care individual mandate declared void',
#  ...}

# %%
def ComputeEntropy(listValues):
  countsDic=collections.Counter(listValues)  
  countValueList=list(countsDic.values())
  totalItems= len(listValues) 
  entropy=0
  for value in countValueList:
    entropy=entropy + -1*(value/totalItems)*math.log(value/totalItems)      

  return entropy

# %%
def getDicWordToClusterEntropy(dic_txt_to_cluster,dic_word_to_txt):
  dic_word_to_clusterEntropy={}
  dic_word_to_cluster_indecies={}

  for word, txtIndecies in dic_word_to_txt.items():
    word_cluster_indecies=[]
    for txtIndex in txtIndecies:
      word_cluster_indecies.append(dic_txt_to_cluster[txtIndex])
    dic_word_to_cluster_indecies[word]=word_cluster_indecies
    dic_word_to_clusterEntropy[word]=ComputeEntropy(word_cluster_indecies)

  #print(dic_word_to_clusterEntropy)
  #print(dic_word_to_cluster_indecies)  

  return [dic_word_to_clusterEntropy, dic_word_to_cluster_indecies]  

def getDicTxtToClass_WordToTxt(listtuple_pred_true_text):
  dic_txt_to_cluster={} 
  dic_word_to_txt={}
  
  for i in range(len(listtuple_pred_true_text)):
    pred_true_txt=listtuple_pred_true_text[i]
    pred=pred_true_txt[0]
    true=pred_true_txt[1]
    words=pred_true_txt[2]
    dic_txt_to_cluster[i]=pred
    #words=txt.split()#=word_tokenize(txt)
    for word in words:
      dic_word_to_txt.setdefault(word, []).append(i)	  
  
  #print("dic_txt_to_cluster")
  #print(dic_txt_to_cluster)
  
  #print("dic_word_to_txt")
  #print(dic_word_to_txt)
  
  return [dic_txt_to_cluster, dic_word_to_txt]

# %%
mstream=1

# %%
def extractHighEntopyWords(dic_word_to_clusterEntropy):
  high_entropy_words=[]
  values= list(dic_word_to_clusterEntropy.values())
  
  mean=0
  std=0
  if(len(values)>=1):
    
    mean=statistics.mean(values)   
    std=statistics.stdev(values)
  
  for word, entropy in dic_word_to_clusterEntropy.items():
    if(mstream):
        if (entropy> 1.0*(mean+std)):
         high_entropy_words.append(word)  
    else: 
        if (entropy> 3.0*(mean+std)):
         high_entropy_words.append(word)  
  print("high_entropy_words="+str(len(high_entropy_words))+", total words="+str(len(dic_word_to_clusterEntropy)))	  
  
  return set(high_entropy_words)

# %%
def ExtractHighClusterEntropyWordNo(dic_txt_to_cluster, dic_word_to_txt):
  dic_word_to_clusterEntropy, dic_word_to_cluster_indecies=getDicWordToClusterEntropy(dic_txt_to_cluster,dic_word_to_txt)
  
  dic_word_to_clusterEntropy, dic_word_to_cluster_indecies=getDicWordToClusterEntropy(dic_txt_to_cluster,dic_word_to_txt)
  
  high_entropy_words=extractHighEntopyWords(dic_word_to_clusterEntropy)
  return high_entropy_words

# %%
threshold_fix = 1.1
threshold_init = 0
outputPath = r"C:\Users\sachin\Desktop\mtp\sachin\result"


class Model:
  
    def removeHighEntropyWordsInClusters(self, documentSet):
      print('removeHighEntropyWordsInClusters')
      dic_txt_to_cluster={}
      dic_word_to_txt={} 	  
      for d in range(self.startDoc, self.currentDoc):
        document = documentSet.documents[d]
        documentID = document.documentID
        cluster = self.z[documentID]
        dic_txt_to_cluster[d]=cluster	
        
        for w in range(document.wordNum):
          wordNo = document.wordIdArray[w]
          if self.n_zv[cluster][wordNo]>0:
            dic_word_to_txt.setdefault(wordNo, []).append(d)

      high_entropy_words=ExtractHighClusterEntropyWordNo(dic_txt_to_cluster, dic_word_to_txt) 
      #print('high_entropy_words', high_entropy_words)
      for d in range(self.startDoc, self.currentDoc):
        document = documentSet.documents[d]
        documentID = document.documentID
        cluster = self.z[documentID]
        wordsRemoved=0
        wordNos=[]		
        for w in range(document.wordNum):
          wordNo = document.wordIdArray[w]
          wordFre = document.wordFreArray[w]
          wordNos.append(wordNo)  
  
          if wordNo in high_entropy_words:
            self.n_zv[cluster][wordNo] -= wordFre
            self.n_z[cluster] -= wordFre		  
             
          if self.n_zv[cluster][wordNo]<=0:
            wordsRemoved+=1   
            del self.n_zv[cluster][wordNo]

        if len(wordNos)==wordsRemoved:
          self.m_z[cluster] -= 1             
        self.checkEmpty(cluster)      
      #'''print("self.n_zv.keys()", len(self.n_zv.keys()), self.n_zv.keys()) #very important aux
      #for cluster in self.n_zv.keys():
        #dicWordNoFreqs = self.n_zv[cluster]
        #for wordNo in dicWordNoFreqs.keys():
          #if dicWordNoFreqs[wordNo]>0:		
            #print("cluster",cluster, wordNo, dicWordNoFreqs[wordNo])'''
       	


    def __init__(self, K, Max_Batch, V, iterNum,alpha0, beta, dataset, ParametersStr, sampleNo, wordsInTopicNum, timefil):
        self.dataset = dataset
        self.ParametersStr = ParametersStr
        self.alpha0 = alpha0
        self.beta = beta
        self.K = K
        self.Kin = K
        self.V = V
        self.iterNum = iterNum
        self.beta0 = float(V) * float(beta)
        self.sampleNo = sampleNo
        self.wordsInTopicNum = copy.deepcopy(wordsInTopicNum)
        self.Max_Batch = Max_Batch  # Max number of batches we will consider
        self.phi_zv = []

        self.batchNum2tweetID = {} # batch num to tweet id
        self.batchNum = 1 # current batch number
        self.readTimeFil(timefil)

    def readTimeFil(self, timefil):
        try:
            with open(timefil) as timef:
                for line in timef:
                    buff = line.strip().split(' ')
                    if buff == ['']:
                        break
                    self.batchNum2tweetID[self.batchNum] = int(buff[1])
                    self.batchNum += 1
            self.batchNum = 1
        except:
            print("No timefil!")
        # print("There are", self.batchNum2tweetID.__len__(), "time points.\n\t", self.batchNum2tweetID)

    def getAveBatch(self, documentSet, AllBatchNum):
        self.batchNum2tweetID.clear()
        temp = self.D_All / AllBatchNum
        _ = 0
        count = 1
        for d in range(self.D_All):
            if _ < temp:
                _ += 1
                continue
            else:
                document = documentSet.documents[d]
                documentID = document.documentID
                self.batchNum2tweetID[count] = documentID
                count += 1
                _ = 0
        self.batchNum2tweetID[count] = -1

    '''
    improvements
    At initialization, V_current has another choices:
    set V_current is the number of words analyzed in the current batch and the number of words in previous batches,
        which means beta0s of each document are different at initialization.
    Before we process each batch, alpha will be recomputed by the function: alpha = alpha0 * docStored
    '''
    def run_MStream(self, documentSet, outputPath, wordList, AllBatchNum):
        self.D_All = documentSet.D  # The whole number of documents
        self.z = {}  # Cluster assignments of each document                 (documentID -> clusterID)
        self.m_z = {}  # The number of documents in cluster z               (clusterID -> number of documents)
        self.n_z = {}  # The number of words in cluster z                   (clusterID -> number of words)
        self.n_zv = {}  # The number of occurrences of word v in cluster z  (n_zv[clusterID][wordID] = number)
        self.currentDoc = 0  # Store start point of next batch
        self.startDoc = 0  # Store start point of this batch
        self.D = 0  # The number of documents currently
        self.K_current = copy.deepcopy(self.K) # the number of cluster containing documents currently
        # self.BatchSet = {} # No need to store information of each batch
        self.word_current = {} # Store word-IDs' list of each batch

        # Get batchNum2tweetID by AllBatchNum
        self.getAveBatch(documentSet, AllBatchNum)
        print("batchNum2tweetID is ", self.batchNum2tweetID)

        while self.currentDoc < self.D_All:
            print("Batch", self.batchNum)
            if self.batchNum not in self.batchNum2tweetID:
                break
            self.intialize(documentSet)
            self.gibbsSampling(documentSet)
            self.removeHighEntropyWordsInClusters(documentSet)
            
            print("\tGibbs sampling successful! Start to saving results.")
            self.output(documentSet, outputPath, wordList, self.batchNum - 1)
            print("\tSaving successful!")
    
    # Compute beta0 for every batch
    def getBeta0(self):
        Words = []
        if self.batchNum < 5:
            for i in range(1, self.batchNum + 1):
                Words = list(set(Words + self.word_current[i]))
        if self.batchNum >= 5:
            for i in range(self.batchNum - 4, self.batchNum + 1):
                Words = list(set(Words + self.word_current[i]))
        return (float(len(list(set(Words)))) * float(self.beta))

    def intialize(self, documentSet):
        self.word_current[self.batchNum] = []
        for d in range(self.currentDoc, self.D_All):
            document = documentSet.documents[d]
            documentID = document.documentID
            # This method is getting beta0 at the beginning of initialization considering the whole words in current batch
            # for w in range(document.wordNum):
            #     wordNo = document.wordIdArray[w]
            #     if wordNo not in self.word_current[self.batchNum]:
            #         self.word_current[self.batchNum].append(wordNo)
            if documentID != self.batchNum2tweetID[self.batchNum]:
                self.D += 1
            else:
                break
        self.beta0 = self.getBeta0()
        self.alpha = self.alpha0 * self.D
        print("\t" + str(self.D) + " documents will be analyze. alpha is" + " %.2f." % self.alpha + "\n\tInitialization.", end='\n')
        for d in range(self.currentDoc, self.D_All):
            document = documentSet.documents[d]
            documentID = document.documentID

            # This method is getting beta0 before each document is initialized
            for w in range(document.wordNum):
                wordNo = document.wordIdArray[w]
                if wordNo not in self.word_current[self.batchNum]:
                    self.word_current[self.batchNum].append(wordNo)
            self.beta0 = self.getBeta0()
            if self.beta0 <= 0:
                print("Wrong V!")
                exit(-1)

            if documentID != self.batchNum2tweetID[self.batchNum]:
                cluster = self.sampleCluster(d, document, documentID, 0)
                self.z[documentID] = cluster
                if cluster not in self.m_z:
                    self.m_z[cluster] = 0
                self.m_z[cluster] += 1
                for w in range(document.wordNum):
                    wordNo = document.wordIdArray[w]
                    wordFre = document.wordFreArray[w]
                    if cluster not in self.n_zv:
                        self.n_zv[cluster] = {}
                    if wordNo not in self.n_zv[cluster]:
                        self.n_zv[cluster][wordNo] = 0
                    self.n_zv[cluster][wordNo] += wordFre
                    if cluster not in self.n_z:
                        self.n_z[cluster] = 0
                    self.n_z[cluster] += wordFre
                if d == self.D_All - 1:
                    self.startDoc = self.currentDoc
                    self.currentDoc = self.D_All
                    self.batchNum += 1
            else:
                self.startDoc = self.currentDoc
                self.currentDoc = d
                self.batchNum += 1
                break

    def run_MStreamF(self, documentSet, outputPath, wordList, AllBatchNum):
        self.D_All = documentSet.D  # The whole number of documents
        self.z = {}  # Cluster assignments of each document                 (documentID -> clusterID)
        self.m_z = {}  # The number of documents in cluster z               (clusterID -> number of documents)
        self.n_z = {}  # The number of words in cluster z                   (clusterID -> number of words)
        self.n_zv = {}  # The number of occurrences of word v in cluster z  (n_zv[clusterID][wordID] = number)
        self.currentDoc = 0  # Store start point of next batch
        self.startDoc = 0  # Store start point of this batch
        self.D = 0  # The number of documents currently
        self.K_current = copy.deepcopy(self.K) # the number of cluster containing documents currently
        self.BatchSet = {} # Store information of each batch
        self.word_current = {} # Store word-IDs' list of each batch

        # Get batchNum2tweetID by AllBatchNum
        self.getAveBatch(documentSet, AllBatchNum)
        print("batchNum2tweetID is ", self.batchNum2tweetID)

        while self.currentDoc < self.D_All:
            print("Batch", self.batchNum)
            if self.batchNum not in self.batchNum2tweetID:
                break
            if self.batchNum <= self.Max_Batch:
                self.BatchSet[self.batchNum] = {}
                self.BatchSet[self.batchNum]['D'] = copy.deepcopy(self.D)
                self.BatchSet[self.batchNum]['z'] = copy.deepcopy(self.z)
                self.BatchSet[self.batchNum]['m_z'] = copy.deepcopy(self.m_z)
                self.BatchSet[self.batchNum]['n_z'] = copy.deepcopy(self.n_z)
                self.BatchSet[self.batchNum]['n_zv'] = copy.deepcopy(self.n_zv)
                self.intialize(documentSet)
                self.gibbsSampling(documentSet)
                #self.removeHighEntropyWordsInClusters(documentSet)
            else:
                # remove influence of batch earlier than Max_Batch
                self.D -= self.BatchSet[self.batchNum - self.Max_Batch]['D']
                for cluster in self.m_z:
                    if cluster in self.BatchSet[self.batchNum - self.Max_Batch]['m_z']:
                        self.m_z[cluster] -= self.BatchSet[self.batchNum - self.Max_Batch]['m_z'][cluster]
                        self.n_z[cluster] -= self.BatchSet[self.batchNum - self.Max_Batch]['n_z'][cluster]
                        for word in self.n_zv[cluster]:
                            if word in self.BatchSet[self.batchNum - self.Max_Batch]['n_zv'][cluster]:
                                self.n_zv[cluster][word] -= \
                                    self.BatchSet[self.batchNum - self.Max_Batch]['n_zv'][cluster][word]
                for cluster in range(self.K):
                    self.checkEmpty(cluster)
                self.BatchSet.pop(self.batchNum - self.Max_Batch)
                self.BatchSet[self.batchNum] = {}
                self.BatchSet[self.batchNum]['D'] = copy.deepcopy(self.D)
                self.BatchSet[self.batchNum]['z'] = copy.deepcopy(self.z)
                self.BatchSet[self.batchNum]['m_z'] = copy.deepcopy(self.m_z)
                self.BatchSet[self.batchNum]['n_z'] = copy.deepcopy(self.n_z)
                self.BatchSet[self.batchNum]['n_zv'] = copy.deepcopy(self.n_zv)
                self.intialize(documentSet)
                self.gibbsSampling(documentSet)
                #self.removeHighEntropyWordsInClusters(documentSet)
            # get influence of only the current batch (remove other influence)
            self.BatchSet[self.batchNum-1]['D'] = self.D - self.BatchSet[self.batchNum-1]['D']
            for cluster in self.m_z:
                if cluster not in self.BatchSet[self.batchNum - 1]['m_z']:
                    self.BatchSet[self.batchNum - 1]['m_z'][cluster] = 0
                if cluster not in self.BatchSet[self.batchNum - 1]['n_z']:
                    self.BatchSet[self.batchNum - 1]['n_z'][cluster] = 0
                self.BatchSet[self.batchNum - 1]['m_z'][cluster] = self.m_z[cluster] - self.BatchSet[self.batchNum - 1]['m_z'][cluster]
                self.BatchSet[self.batchNum - 1]['n_z'][cluster] = self.n_z[cluster] - self.BatchSet[self.batchNum - 1]['n_z'][cluster]
                if cluster not in self.BatchSet[self.batchNum - 1]['n_zv']:
                    self.BatchSet[self.batchNum - 1]['n_zv'][cluster] = {}
                for word in self.n_zv[cluster]:
                    if word not in self.BatchSet[self.batchNum - 1]['n_zv'][cluster]:
                        self.BatchSet[self.batchNum - 1]['n_zv'][cluster][word] = 0
                    self.BatchSet[self.batchNum - 1]['n_zv'][cluster][word] = self.n_zv[cluster][word] - self.BatchSet[self.batchNum - 1]['n_zv'][cluster][word]
            print("\tGibbs sampling successful! Start to saving results.")
            self.output(documentSet, outputPath, wordList, self.batchNum - 1)
            print("\tSaving successful!")
    def gibbsSampling(self, documentSet):
        for i in range(self.iterNum):
            print("\titer is ", i+1, end='\n')
            for d in range(self.startDoc, self.currentDoc):
                document = documentSet.documents[d]
                documentID = document.documentID
                cluster = self.z[documentID]
                self.m_z[cluster] -= 1
                for w in range(document.wordNum):
                    wordNo = document.wordIdArray[w]
                    wordFre = document.wordFreArray[w]
                    self.n_zv[cluster][wordNo] -= wordFre
                    self.n_z[cluster] -= wordFre
                self.checkEmpty(cluster)
                if i != self.iterNum - 1:  # if not last iteration
                    cluster = self.sampleCluster(d, document, documentID, 0)
                elif i == self.iterNum - 1:  # if last iteration
                    cluster = self.sampleCluster(d, document, documentID, 1)
                self.z[documentID] = cluster
                if cluster not in self.m_z:
                    self.m_z[cluster] = 0
                self.m_z[cluster] += 1
                for w in range(document.wordNum):
                    wordNo = document.wordIdArray[w]
                    wordFre = document.wordFreArray[w]
                    if cluster not in self.n_zv:
                        self.n_zv[cluster] = {}
                    if wordNo not in self.n_zv[cluster]:
                        self.n_zv[cluster][wordNo] = 0
                    if cluster not in self.n_z:
                        self.n_z[cluster] = 0
                    self.n_zv[cluster][wordNo] += wordFre
                    self.n_z[cluster] += wordFre
        return

    def sampleCluster(self, d, document, documentID, isLast):
        prob = [float(0.0)] * (self.K + 1)
        for cluster in range(self.K):
            if cluster not in self.m_z or self.m_z[cluster] == 0:
                prob[cluster] = 0
                continue
            prob[cluster] = self.m_z[cluster] #/ (self.D - 1 + self.alpha)
            valueOfRule2 = 1.0
            i = 0
            for w in range(document.wordNum):
                wordNo = document.wordIdArray[w]
                wordFre = document.wordFreArray[w]
                for j in range(wordFre):
                    if wordNo not in self.n_zv[cluster]:
                        self.n_zv[cluster][wordNo] = 0
                    valueOfRule2 *= (self.n_zv[cluster][wordNo] + self.beta + j) / (self.n_z[cluster] + self.beta0 + i)
                    i += 1
            prob[cluster] *= valueOfRule2
        prob[self.K] = self.alpha #/ (self.D - 1 + self.alpha)
        valueOfRule2 = 1.0
        i = 0
        for w in range(document.wordNum):
            wordFre = document.wordFreArray[w]
            for j in range(wordFre):
                valueOfRule2 *= (self.beta + j) / (self.beta0 + i)
                i += 1
        prob[self.K] *= valueOfRule2

        allProb = 0 # record the amount of all probabilities
        prob_normalized = [] # record normalized probabilities
        for k in range(self.K+1):
            allProb += prob[k]
        for k in range(self.K + 1):
            prob_normalized.append(prob[k]/allProb)

        kChoosed = 0
        if isLast == 0:
            for k in range(1, self.K + 1):
                prob[k] += prob[k - 1]
            thred = random.random() * prob[self.K]
            while kChoosed < self.K + 1:
                if thred < prob[kChoosed]:
                    break
                kChoosed += 1
            if kChoosed == self.K:
                self.K += 1
                self.K_current += 1
        else:
            bigPro = prob[0]
            for k in range(1, self.K + 1):
                if prob[k] > bigPro:
                    bigPro = prob[k]
                    kChoosed = k
            if kChoosed == self.K:
                self.K += 1
                self.K_current += 1
        return kChoosed

    # Clear the useless cluster
    def checkEmpty(self, cluster):
        if cluster in self.n_z and self.m_z[cluster] == 0:
            self.K_current -= 1
            self.m_z.pop(cluster)
            if cluster in self.n_z:
                self.n_z.pop(cluster)
                self.n_zv.pop(cluster)

    def output(self, documentSet, outputPath, wordList, batchNum):
        outputDir = outputPath + "/" + self.dataset + self.ParametersStr + "Batch" + str(batchNum) + "/"
        try:
            isExists = os.path.exists(outputDir)
            if not isExists:
                os.makedirs(outputDir)
                print("\tCreate directory:", outputDir)
        except:
            print("ERROR: Failed to create directory:", outputDir)
        self.outputClusteringResult(outputDir, documentSet)
        self.estimatePosterior()
        try:
            self.outputPhiWordsInTopics(outputDir, wordList, self.wordsInTopicNum)
        except:
            print("\tOutput Phi Words Wrong!")
        self.outputSizeOfEachCluster(outputDir, documentSet)

    def estimatePosterior(self):
        self.phi_zv = {}
        for cluster in self.n_zv:
            n_z_sum = 0
            if self.m_z[cluster] != 0:
                if cluster not in self.phi_zv:
                    self.phi_zv[cluster] = {}
                for v in self.n_zv[cluster]:
                    if self.n_zv[cluster][v] != 0:
                        n_z_sum += self.n_zv[cluster][v]
                for v in self.n_zv[cluster]:
                    if self.n_zv[cluster][v] != 0:
                        self.phi_zv[cluster][v] = float(self.n_zv[cluster][v] + self.beta) / float(n_z_sum + self.beta0)

    def getTop(self, array, rankList, Cnt):
        index = 0
        m = 0
        while m < Cnt and m < len(array):
            max = 0
            for no in array:
                if (array[no] > max and no not in rankList):
                    index = no
                    max = array[no]
            rankList.append(index)
            m += 1

    def outputPhiWordsInTopics(self, outputDir, wordList, Cnt):
        outputfiledir = outputDir + str(self.dataset) + "SampleNo" + str(self.sampleNo) + "PhiWordsInTopics.txt"
        writer = open(outputfiledir, 'w')
        for k in range(self.K):
            rankList = []
            if k not in self.phi_zv:
                continue
            topicline = "Topic " + str(k) + ":\n"
            writer.write(topicline)
            self.getTop(self.phi_zv[k], rankList, Cnt)
            for i in range(rankList.__len__()):
                tmp = "\t" + wordList[rankList[i]] + "\t" + str(self.phi_zv[k][rankList[i]])
                writer.write(tmp + "\n")
        writer.close()

    def outputSizeOfEachCluster(self, outputDir, documentSet):
        outputfile = outputDir + str(self.dataset) + "SampleNo" + str(self.sampleNo) + "SizeOfEachCluster.txt"
        writer = open(outputfile, 'w')
        topicCountIntList = []
        for cluster in range(self.K):
            if cluster in self.m_z and self.m_z[cluster] != 0:
                topicCountIntList.append([cluster, self.m_z[cluster]])
        line = ""
        for i in range(topicCountIntList.__len__()):
            line += str(topicCountIntList[i][0]) + ":" + str(topicCountIntList[i][1]) + ",\t"
        writer.write(line + "\n\n")
        line = ""
        topicCountIntList.sort(key = lambda tc: tc[1], reverse = True)
        for i in range(topicCountIntList.__len__()):
            line += str(topicCountIntList[i][0]) + ":" + str(topicCountIntList[i][1]) + ",\t"
        writer.write(line + "\n")
        writer.close()

    def outputClusteringResult(self, outputDir, documentSet):
        outputPath = outputDir+str(self.dataset)+"SampleNo"+str(self.sampleNo)+"ClusteringResult.txt"
        #os.makedirs(os.path.dirname(outputPath), exist_ok=True)
        writer = open(outputPath, 'w')
        for d in range(self.startDoc, self.currentDoc):
            documentID = documentSet.documents[d].documentID
            cluster = self.z[documentID]
            writer.write(str(documentID) + " " + str(cluster) + "\n")
        writer.close()

# %%
class MStream:
    #dataDir = "data/"
    dataDir = r"C:\Users\sachin\Desktop\mtp\sachin\data"
    dataset = "Tweets-T"

    def __init__(self, K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum):
        self.K = K
        self.MaxBatch = MaxBatch
        self.AllBatchNum = AllBatchNum
        self.alpha = alpha
        self.beta = beta
        self.iterNum = iterNum
        self.dataset = dataset
        self.timefil = timefil
        self.sampleNum = sampleNum
        self.wordsInTopicNum = wordsInTopicNum
        self.wordList = []
        self.wordToIdMap = {}

    def getDocuments(self):
        self.documentSet = DocumentSet(os.path.join(self.dataDir,self.dataset), self.wordToIdMap, self.wordList)
        self.V = self.wordToIdMap.__len__()

    def runMStream(self, sampleNo, outputPath):
        ParametersStr = "K" + str(self.K) + "iterNum" + str(self.iterNum) + \
                        "SampleNum" + str(self.sampleNum) + "alpha" + str(round(self.alpha, 3)) + \
                        "beta" + str(round(self.beta, 3)) + "BatchNum" + str(self.AllBatchNum) + "BatchSaved" + str(self.MaxBatch)
        model = Model(self.K, self.MaxBatch, self.V, self.iterNum, self.alpha, self.beta, self.dataset,
                      ParametersStr, sampleNo, self.wordsInTopicNum, self.dataDir + self.timefil)
        model.run_MStream(self.documentSet, outputPath, self.wordList, self.AllBatchNum)

    def runMStreamF(self, sampleNo, outputPath):
        ParametersStr = "K" + str(self.K) + "iterNum" + str(self.iterNum) + \
                        "SampleNum" + str(self.sampleNum) + "alpha" + str(round(self.alpha, 3)) + \
                        "beta" + str(round(self.beta, 3)) + "BatchNum" + str(self.AllBatchNum) + "BatchSaved" + str(self.MaxBatch)
        model = Model(self.K, self.MaxBatch, self.V, self.iterNum, self.alpha, self.beta, self.dataset,
                      ParametersStr, sampleNo, self.wordsInTopicNum, self.dataDir + self.timefil)
        model.run_MStreamF(self.documentSet, outputPath, self.wordList, self.AllBatchNum)

# %%
outputPath = r"C:\Users\sachin\Desktop\mtp\sachin\result"

# dataset = "TREC"
# dataset = "TREC-T"
#dataset = "News"
# dataset = "News-T"
dataset="Tweets-T"
timefil = "timefil"
MaxBatch = 2 # The number of saved batches + 1
AllBatchNum = 16 # The number of batches you want to devided the dataset to
alpha = 0.03
beta = 0.03
iterNum = 5
sampleNum = 1
wordsInTopicNum = 5
K = 0 


def runMStream(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum):
    mstream = MStream(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
    mstream.getDocuments()
    for sampleNo in range(1, sampleNum+1):
        print("SampleNo:"+str(sampleNo))
        mstream.runMStream(sampleNo, outputPath)
def runMStreamF(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum):
    mstream = MStream(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
    mstream.getDocuments()
    for sampleNo in range(1, sampleNum+1):
        print("SampleNo:"+str(sampleNo))
        mstream.runMStreamF(sampleNo, outputPath)

# %%
def runWithAlphaScale(beta, K, MaxBatch, AllBatchNum, iterNum, sampleNum, dataset, timefil, wordsInTopicNum):
    parameters = []
    timeArrayOfParas = []

    p = 0.01
    while p <= 0.051:
        alpha = p
        parameters.append(p)
        print("alpha:", alpha, "\tp:", p)
        mstream = MStream(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
        mstream.getDocuments()
        timeArray = []
        for sampleNo in range(1, sampleNum + 1):
            print("SampleNo:", sampleNo)
            startTime = time.time()
            mstream.runMStreamF(sampleNo, outputPath)
            endTime = time.time()
            timeArray.append(int(endTime - startTime))
        timeArrayOfParas.append(timeArray)
        p += 0.001

    fileParameters = "MStreamDiffAlpha" + "K" + str(K) + "iterNum" + str(iterNum) + "SampleNum" + \
                     str(sampleNum) + "beta" + str(round(beta, 3)) + \
                        "BatchNum" + str(AllBatchNum) + "BatchSaved" + str(MaxBatch)
    outTimePath = outputPath + "Time" + dataset + fileParameters + ".txt"
    writer = open(outTimePath, 'w')
    parasNum = parameters.__len__()
    for i in range(parasNum):
        temp_obj = {}
        temp_obj['parameter'] = parameters[i]
        temp_obj['Time'] = timeArrayOfParas[i]
        temp_json = json.dumps(temp_obj)
        writer.write(temp_json)
        writer.write('\n')
    writer.close()

# %%
runMStream(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
#runMStreamF(K, MaxBatch, AllBatchNum, alpha, beta, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
#runWithAlphaScale(beta, K, MaxBatch, AllBatchNum, iterNum, sampleNum, dataset, timefil, wordsInTopicNum)
# Out:
# number of documents is  30322
# SampleNo:1
# No timefil!
# batchNum2tweetID is  {1: 1897, 2: 3794, 3: 5691, 4: 7588, 5: 9485, 6: 11382, 7: 13279, 8: 15176, 9: 17073, 10: 18970, 11: 20867, 12: 22764, 13: 24661, 14: 26558, 15: 28455, 16: -1}
# Batch 1
# 	1896 documents will be analyze. alpha is 56.88.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 2
# 	3793 documents will be analyze. alpha is 113.79.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 3
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 4
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 5
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 6
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 7
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 8
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 9
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 10
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 11
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 12
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 13
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 14
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 15
# 	3794 documents will be analyze. alpha is 113.82.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
# Batch 16
# 	3765 documents will be analyze. alpha is 112.95.
# 	Initialization.
# 	iter is  1
# 	iter is  2
# 	iter is  3
# 	iter is  4
# 	iter is  5
# 	Gibbs sampling successful! Start to saving results.
# 	Saving successful!
